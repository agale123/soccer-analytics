# %%
import nwslpy
stats = nwslpy.load_player_season_stats("RGN", "2022")[["player_id", "goals"]]
stats = stats.set_index("player_id").join(nwslpy.load_players())
stats.sort_values("goals", ascending=False)
# Out:
#     player_id  goals
# 0         382      0
# 1         554      0
# 2         667      1
# 3         426      7
# 4         150      0
# 5         661      0
# 6         666      0
# 7         487      0
# 8         153      4
# 9         209      1
# 10        526      0
# 11         49      1
# 12        721      2
# 13        500      2
# 14        335      1
# 15        261      5
# 16        143      0
# 17        601      0
# 18        563      0
# 19        479      0
# 20        140      7
# 21        123      0
# 22        599      0
# 23        665      0
# 24        481      1

# %%
# Out:
#            goals  player_first_name   player_last_name  \
# player_id
# 140            7         Megan Anna            Rapinoe
# 426            7            Bethany             Balcer
# 261            5  Rosemary Kathleen            Lavelle
# 153            4       Jessica Anne           Fishlock
# 721            2      Jordyn Pamela            Huitema
# 500            2            Tziarra               King
# 209            1              Tobin       Powell Heath
# 335            1      Veronica Anne             Latsko
# 49             1    Sofia Christine             Huerta
# 481            1               Ally               Watt
# 667            1             Olivia             Athens
# 526            0           Samantha              Hiatt
# 487            0       Alana Simone               Cook
# 554            0           Angelina  Alonso Costantino
# 666            0             Marley            Canales
# 661            0             Ryanne              Brown
# ...

# %%
nwslpy.load_players()
# Out:
#            player_first_name player_last_name player_short_first_name  \
# player_id
# 1          Angela Marguerite            Salem                  Angela
# 2                     Louise       Schillgard                  Louise
# 3            Natasha Khalila            Dowie                 Natasha
# 4                   Kyah Pam            Simon                    Kyah
# 5              Kylie Allyssa            Strom                   Kylie
# ...                      ...              ...                     ...
# 732                   Shuang             Wang                  Shuang
# 733             Jaedyn Reese             Shaw                  Jaedyn
# 734                   Jackie        Altschuld                  Jackie
# 735                    Katie           Murray                   Katie
# 736                   Andrea          Frerker                  Andrea
#
#           player_short_last_name player_match_name player_nationality  \
# player_id
# ...
