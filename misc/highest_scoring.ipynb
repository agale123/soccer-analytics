# %%
from common import Data

# %%
df = Data.get_nwsl_matches()
df["total_score"] = df["home_score"] + df["away_score"]
df.groupby("date").agg(total_score=("total_score", "sum")).sort_values("total_score")
# Out:
#             total_score
# date
# 2022-06-07            0
# 2015-08-23            0
# 2023-07-02            0
# 2015-08-27            0
# 2022-08-12            0
# ...                 ...
# 2017-05-27           17
# 2014-07-20           17
# 2023-04-01           18
# 2017-06-17           20
# 2017-09-30           21
#
# [658 rows x 1 columns]

# %%
df[df["date"] == "2017-09-30"]
# Out:
#           date   time season home  away  home_score  away_score  \
# 513 2017-09-30  12:30   2017  POR   CHI           3           1
# 514 2017-09-30  19:00   2017  BOS  NJNY           3           4
# 515 2017-09-30  19:00   2017  WAS   RGN           2           3
# 516 2017-09-30  19:30   2017   NC   ORL           2           3
#
#      home_penalty_score  away_penalty_score  home_xg  away_xg  \
# 513                 0.0                 0.0      NaN      NaN
# 514                 0.0                 0.0      NaN      NaN
# 515                 0.0                 0.0      NaN      NaN
# 516                 0.0                 0.0      NaN      NaN
#
#                referee  attendance              stadium  is_forfeit  \
# 513    Elvis Osmanovic     21144.0      Providence Park       False
# 514          Karen Abt      3497.0         Jordan Field       False
# 515  Robinson Khongsai      3780.0  Maryland SoccerPlex       False
# ...
