# %%
import nwslpy
import pandas as pd
import datetime

# %%
# Collect raw data
matches = nwslpy.load_matches()
matches = matches[
    matches["season"].apply(lambda x: "Fall" not in x and "Challenge" not in x)
]
teams = nwslpy.load_teams()

# %%
# TODO: update to read data directly rather than from nwslpy
matches[matches["season"] == "2023"].iloc[-30:-10]
# Out:
#                                                     home_team_id  \
# match_id
# racing-louisville-fc-vs-portland-thorns-fc-2023...          14.0
# washington-spirit-vs-chicago-red-stars-2023-09-03            9.0
# ol-reign-vs-orlando-pride-2023-09-03                         6.0
# san-diego-wave-fc-vs-houston-dash-2023-09-03                16.0
# racing-louisville-fc-vs-houston-dash-2023-09-15             14.0
# nj-ny-gotham-fc-vs-washington-spirit-2023-09-16              5.0
# san-diego-wave-fc-vs-kansas-city-current-2023-0...          16.0
# portland-thorns-fc-vs-ol-reign-2023-09-16                    8.0
# chicago-red-stars-vs-angel-city-fc-2023-09-17                2.0
# orlando-pride-vs-north-carolina-courage-2023-09-17           7.0
# angel-city-fc-vs-orlando-pride-2023-09-21                   15.0
# washington-spirit-vs-kansas-city-current-2023-0...           9.0
# chicago-red-stars-vs-racing-louisville-fc-2023-...           2.0
# portland-thorns-fc-vs-san-diego-wave-fc-2023-09-30           8.0
# nj-ny-gotham-fc-vs-houston-dash-2023-10-01                   5.0
# ol-reign-vs-north-carolina-courage-2023-10-01                6.0
# racing-louisville-fc-vs-orlando-pride-2023-10-06            14.0
# ol-reign-vs-washington-spirit-2023-10-06                     6.0
# portland-thorns-fc-vs-nj-ny-gotham-fc-2023-10-07             8.0
# north-carolina-courage-vs-san-diego-wave-fc-202...          11.0
#
#                                                     away_team_id  \
# match_id
# racing-louisville-fc-vs-portland-thorns-fc-2023...           8.0
# washington-spirit-vs-chicago-red-stars-2023-09-03            2.0
# ol-reign-vs-orlando-pride-2023-09-03                         7.0
# san-diego-wave-fc-vs-houston-dash-2023-09-03                 4.0
# racing-louisville-fc-vs-houston-dash-2023-09-15              4.0
# nj-ny-gotham-fc-vs-washington-spirit-2023-09-16              9.0
# san-diego-wave-fc-vs-kansas-city-current-2023-0...          13.0
# portland-thorns-fc-vs-ol-reign-2023-09-16                    6.0
# chicago-red-stars-vs-angel-city-fc-2023-09-17               15.0
# orlando-pride-vs-north-carolina-courage-2023-09-17          11.0
# angel-city-fc-vs-orlando-pride-2023-09-21                    7.0
# washington-spirit-vs-kansas-city-current-2023-0...          13.0
# chicago-red-stars-vs-racing-louisville-fc-2023-...          14.0
# portland-thorns-fc-vs-san-diego-wave-fc-2023-09-30          16.0
# nj-ny-gotham-fc-vs-houston-dash-2023-10-01                   4.0
# ol-reign-vs-north-carolina-courage-2023-10-01               11.0
# racing-louisville-fc-vs-orlando-pride-2023-10-06             7.0
# ol-reign-vs-washington-spirit-2023-10-06                     9.0
# portland-thorns-fc-vs-nj-ny-gotham-fc-2023-10-07             5.0
# north-carolina-courage-vs-san-diego-wave-fc-202...          16.0
#
#                                                                kickoff  \
# match_id
# racing-louisville-fc-vs-portland-thorns-fc-2023... 2023-09-02 19:30:00
# washington-spirit-vs-chicago-red-stars-2023-09-03  2023-09-03 17:00:00
# ol-reign-vs-orlando-pride-2023-09-03               2023-09-03 18:00:00
# san-diego-wave-fc-vs-houston-dash-2023-09-03       2023-09-03 20:00:00
# racing-louisville-fc-vs-houston-dash-2023-09-15    2023-09-15 19:30:00
# nj-ny-gotham-fc-vs-washington-spirit-2023-09-16    2023-09-16 19:30:00
# san-diego-wave-fc-vs-kansas-city-current-2023-0... 2023-09-16 22:00:00
# portland-thorns-fc-vs-ol-reign-2023-09-16          2023-09-16 22:30:00
# chicago-red-stars-vs-angel-city-fc-2023-09-17      2023-09-17 18:00:00
# orlando-pride-vs-north-carolina-courage-2023-09-17 2023-09-17 19:00:00
# angel-city-fc-vs-orlando-pride-2023-09-21          2023-09-21 22:00:00
# washington-spirit-vs-kansas-city-current-2023-0... 2023-09-30 19:00:00
# chicago-red-stars-vs-racing-louisville-fc-2023-... 2023-09-30 20:00:00
# portland-thorns-fc-vs-san-diego-wave-fc-2023-09-30 2023-09-30 22:30:00
# nj-ny-gotham-fc-vs-houston-dash-2023-10-01         2023-10-01 18:30:00
# ol-reign-vs-north-carolina-courage-2023-10-01      2023-10-01 20:00:00
# racing-louisville-fc-vs-orlando-pride-2023-10-06   2023-10-06 19:30:00
# ol-reign-vs-washington-spirit-2023-10-06           2023-10-06 22:00:00
# portland-thorns-fc-vs-nj-ny-gotham-fc-2023-10-07   2023-10-07 17:00:00
# north-carolina-courage-vs-san-diego-wave-fc-202... 2023-10-07 19:00:00
#
#                                                     home_team_score  \
# match_id
# racing-louisville-fc-vs-portland-thorns-fc-2023...                2
# washington-spirit-vs-chicago-red-stars-2023-09-03                 0
# ol-reign-vs-orlando-pride-2023-09-03                              0
# san-diego-wave-fc-vs-houston-dash-2023-09-03                      0
# racing-louisville-fc-vs-houston-dash-2023-09-15                   0
# nj-ny-gotham-fc-vs-washington-spirit-2023-09-16                   0
# san-diego-wave-fc-vs-kansas-city-current-2023-0...                0
# portland-thorns-fc-vs-ol-reign-2023-09-16                         0
# chicago-red-stars-vs-angel-city-fc-2023-09-17                     0
# orlando-pride-vs-north-carolina-courage-2023-09-17                0
# angel-city-fc-vs-orlando-pride-2023-09-21                         0
# washington-spirit-vs-kansas-city-current-2023-0...                0
# chicago-red-stars-vs-racing-louisville-fc-2023-...                0
# portland-thorns-fc-vs-san-diego-wave-fc-2023-09-30                0
# nj-ny-gotham-fc-vs-houston-dash-2023-10-01                        0
# ol-reign-vs-north-carolina-courage-2023-10-01                     0
# racing-louisville-fc-vs-orlando-pride-2023-10-06                  0
# ol-reign-vs-washington-spirit-2023-10-06                          0
# portland-thorns-fc-vs-nj-ny-gotham-fc-2023-10-07                  0
# north-carolina-courage-vs-san-diego-wave-fc-202...                0
#
#                                                     away_team_score season
# match_id
# racing-louisville-fc-vs-portland-thorns-fc-2023...                1   2023
# washington-spirit-vs-chicago-red-stars-2023-09-03                 0   2023
# ol-reign-vs-orlando-pride-2023-09-03                              0   2023
# san-diego-wave-fc-vs-houston-dash-2023-09-03                      0   2023
# racing-louisville-fc-vs-houston-dash-2023-09-15                   0   2023
# nj-ny-gotham-fc-vs-washington-spirit-2023-09-16                   0   2023
# san-diego-wave-fc-vs-kansas-city-current-2023-0...                0   2023
# portland-thorns-fc-vs-ol-reign-2023-09-16                         0   2023
# chicago-red-stars-vs-angel-city-fc-2023-09-17                     0   2023
# orlando-pride-vs-north-carolina-courage-2023-09-17                0   2023
# angel-city-fc-vs-orlando-pride-2023-09-21                         0   2023
# washington-spirit-vs-kansas-city-current-2023-0...                0   2023
# chicago-red-stars-vs-racing-louisville-fc-2023-...                0   2023
# portland-thorns-fc-vs-san-diego-wave-fc-2023-09-30                0   2023
# nj-ny-gotham-fc-vs-houston-dash-2023-10-01                        0   2023
# ol-reign-vs-north-carolina-courage-2023-10-01                     0   2023
# racing-louisville-fc-vs-orlando-pride-2023-10-06                  0   2023
# ol-reign-vs-washington-spirit-2023-10-06                          0   2023
# portland-thorns-fc-vs-nj-ny-gotham-fc-2023-10-07                  0   2023
# north-carolina-courage-vs-san-diego-wave-fc-202...                0   2023

# %%
# Remove duplicate matches
matches = matches.drop("angel-city-fc-vs-chicago-red-stars-2023-06-04")
matches = matches.drop("chicago-red-stars-vs-north-carolina-courage-2023-06-09")

# %%
# Transform data into date, team, season, points

# Remove playoff games
playoffs = {
    "2023 Challenge Cup": datetime.date(2023, 8, 7),
    "2023": datetime.date(2023, 10, 21),
    "2022 Challenge Cup": datetime.date(2022, 5, 3),
    "2022": datetime.date(2022, 10, 15),
    "2021 Challenge Cup": datetime.date(2021, 5, 7),
    "2021": datetime.date(2021, 11, 6),
    "2020 Fall Series": datetime.date(2020, 10, 18),
    "2020 Challenge Cup": datetime.date(2020, 7, 16),
    "2019": datetime.date(2019, 10, 19),
    "2018": datetime.date(2018, 9, 14),
    "2017": datetime.date(2017, 10, 6),
    "2016": datetime.date(2016, 9, 29),
}
matches["is_playoff"] = matches.apply(
    lambda row: row["kickoff"] > pd.Timestamp(playoffs[row["season"]]), axis=1
)
matches = matches[~matches["is_playoff"]]
matches = matches[
    [
        "home_team_id",
        "away_team_id",
        "kickoff",
        "home_team_score",
        "away_team_score",
        "season",
    ]
]

# Filter to desired columns
def get_points(team, opp):
    if team > opp:
        return 3
    elif team < opp:
        return 0
    else:
        return 1


home = matches.copy().set_index("home_team_id").join(teams)
home["points"] = home.apply(
    lambda x: get_points(x["home_team_score"], x["away_team_score"]), axis=1
)
home = home[["kickoff", "team_abbreviation", "season", "points"]]

away = matches.copy().set_index("away_team_id").join(teams)
away["points"] = away.apply(
    lambda x: get_points(x["away_team_score"], x["home_team_score"]), axis=1
)
away = away[["kickoff", "team_abbreviation", "season", "points"]]
df = pd.concat([home, away])

# Rename columns
df = df.rename(columns={"kickoff": "date", "team_abbreviation": "team"})
df["date"] = pd.to_datetime(df["date"]).dt.date
df = df.sort_values("date")
df
# Out:
#             date team season  points
# 2.0   2016-04-16  CHI   2016       0
# 9.0   2016-04-16  WAS   2016       3
# 10.0  2016-04-16  WNY   2016       3
# 3.0   2016-04-16   KC   2016       0
# 1.0   2016-04-16  BOS   2016       0
# ...          ...  ...    ...     ...
# 8.0   2023-10-15  POR   2023       1
# 11.0  2023-10-15   NC   2023       1
# 13.0  2023-10-15  KCC   2023       1
# 15.0  2023-10-15   LA   2023       1
# 16.0  2023-10-15   SD   2023       1
#
# [1640 rows x 4 columns]

# %%
# Add in fbref data
fbref = pd.read_csv("fbref.csv")
fbref = fbref[~fbref["is_playoff"]]
home = fbref.copy()
home["points"] = home.apply(
    lambda x: get_points(x["home_team_score"], x["away_team_score"]), axis=1
)
home["team"] = home["home_team"]
home = home[["kickoff", "team", "season", "points"]]

away = fbref.copy()
away["points"] = away.apply(
    lambda x: get_points(x["away_team_score"], x["home_team_score"]), axis=1
)
away["team"] = away["away_team"]
away = away[["kickoff", "team", "season", "points"]]
df2 = pd.concat([home, away])
df2 = df2.rename(columns={"kickoff": "date"})
df2["date"] = pd.to_datetime(df2["date"]).dt.date
df2 = df2.sort_values("date")
df2

df = pd.concat([df, df2])

# %%
def cumulative_sum(lists):
    cu_list = []
    length = len(lists)
    cu_list = [sum(lists[0:x:1]) for x in range(0, length + 1)]
    return cu_list[1:]


def get_points(team, season):
    subset = df[(df["team"] == team) & (df["season"] == season)]
    return cumulative_sum(list(subset["points"]))

matches_per_season = {
    "2013": 22,
    "2014": 24,
    "2015": 20,
    "2016": 20,
    "2017": 24,
    "2018": 24,
    "2019": 24,
    "2021": 24,
    "2022": 22,
    "2023": 22,
}

# Aggregate by team, season
results = pd.DataFrame([], columns=["team", "season", "points"])
for i, row in df.groupby(["team", "season"]).count().reset_index().iterrows():
    points = get_points(row["team"], row["season"])
    if len(points) != matches_per_season[str(row["season"])]:
        raise Error("incorrect number of matches")
    results.loc[len(results.index)] = [
        row["team"],
        row["season"],
        points,
    ]

results = results.sort_values(["season", "team"])
# Out:
# /home/agale/.local/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %%
# Write to a file
results.to_csv("final.csv", index=False)
