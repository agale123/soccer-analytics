# %%
import pandas as pd

# %%
df = pd.read_csv("data/stats_2023.csv")
df
# Out:
#       result_id  player_id  avg_speed  distance_high_speed_running  \
# 0        131872     252502       5.99                  2172.333564
# 1        131872     252503       0.00                     0.000000
# 2        131872     252519       6.43                  2341.053301
# 3        131872     295585       5.54                  1649.667516
# 4        131872     296646       0.00                     0.000000
# ...         ...        ...        ...                          ...
# 2867     134412     431333       0.00                     0.000000
# 2868     134412     459604       5.21                  1029.388437
# 2869     134412     459605       0.00                     0.000000
# 2870     134412     467287       0.00                     0.000000
# 2871     134412     467297       0.00                     0.000000
#
#       distance_high_speed_sprinting  distance_jogging  \
# 0                        220.847220       3625.909812
# ...

# %%
df.columns
# Out:
# Index(['result_id', 'player_id', 'avg_speed', 'distance_high_speed_running',
#        'distance_high_speed_sprinting', 'distance_jogging',
#        'distance_low_speed_sprinting', 'distance_walking', 'speed_runs',
#        'sprints', 'top_speed', 'total_distance',
#        'receptions_under_indirect_pressure',
#        'receptions_under_direct_pressure', 'received_offers_to_receive',
#        'linebreaks_attempted_all_lines', 'offers_to_receive_in_between',
#        'distributions_completed_under_pressure', 'offers_to_receive_in_behind',
#        'goalkeeper_defensive_actions_outside_penalty_area',
#        'linebreaks_attempted', 'linebreaks_attempted_attacking_line',
#        'linebreaks_attempted_attacking_line_completed',
#        'linebreaks_attempted_midfield_line_completed',
#        'linebreaks_attempted_defensive_line_completed',
#        'linebreaks_attempted_under_pressure', 'offers_to_receive_inside',
#        'offers_to_receive_outside',
# ...

# %%
df[df["own_goals"] > 0]
# Out:
#       result_id  player_id  avg_speed  distance_high_speed_running  \
# 201      131876     467143       6.27                  1201.703040
# 398      131880     467589       5.51                  1948.300152
# 592      131884     467481       5.49                  2026.488442
# 1842     131912     467076       5.23                  2090.139990
# 1929     131914     467233       5.13                  1433.455020
# 1943     131914     467262       6.22                  2760.147000
# 2190     131920     396914       5.89                  2074.465848
# 2247     131921     420291       7.47                  3160.718780
#
#       distance_high_speed_sprinting  distance_jogging  \
# 201                      107.026677       2644.372575
# 398                      126.134970       3912.124608
# 592                      215.234596       3243.111116
# 1842                     206.513610       3277.361730
# 1929                     276.877620       3329.541000
# ...

# %%
df.groupby(["team", "date"]).sum()["total_distance"].sort_values()
# Out:
# team  date
# COL   2023-08-08T18:00:00Z     91488.36
# JAM   2023-08-08T18:00:00Z     94773.88
# ITA   2023-07-24T18:00:00Z     94787.31
# KOR   2023-07-30T14:00:00Z     95224.00
# ESP   2023-08-15T20:00:00Z     95816.01
#                                 ...
# USA   2023-08-06T19:00:00Z    136604.32
# AUS   2023-08-12T17:00:00Z    136724.54
# SWE   2023-08-06T19:00:00Z    140177.35
# NED   2023-08-11T13:00:00Z    145540.52
# ESP   2023-08-11T13:00:00Z    149932.75
# Name: total_distance, Length: 128, dtype: float64

# %%
df["goals_inside_the_penalty_area"].sum()
# Out:
# 138.0

# %%
df["goals_outside_the_penalty_area"].sum()
# Out:
# 18.0

# %%
df["penalties_scored"].sum()
# Out:
# 20.0
