# %%
import pandas as pd

# %%
df = pd.read_csv("data/stats_2023.csv")
df
# Out:
#      result_id  player_id  avg_speed  distance_high_speed_running  \
# 0       131872     467661       5.59                  1892.743298
# 1       131872     420294       0.00                     0.000000
# 2       131872     467662       0.00                     0.000000
# 3       131872     467653       5.75                  2082.699250
# 4       131872     467666       0.00                     0.000000
# ..         ...        ...        ...                          ...
# 268     131896     466811       0.00                     0.000000
# 269     131896     466806       5.73                   996.392320
# 270     131896     466786       5.54                   651.356156
# 271     131896     466779       6.93                  1037.676544
# 272     131896     466792       0.00                     0.000000
#
#      distance_high_speed_sprinting  distance_jogging  \
# 0                       293.136394       3384.648332
# 1                         0.000000          0.000000
# ...

# %%
df[df["result_id"] == 131896][["distance_walking", "player_name"]].sort_values("distance_walking", ascending=False)
# Out:
#      distance_walking            player_name
# 253       2245.546160         Thi Loan HOANG
# 250       2087.714508          Thi Thao THAI
# 255       2069.084631         Thi Diem My LE
# 254       2063.482014           Thi Thu TRAN
# 232       1985.200764          Lindsey HORAN
# 228       1943.218581           Sophia SMITH
# 252       1906.866922      Thi Thu Thao TRAN
# 231       1903.644709          Andi SULLIVAN
# 262       1857.579264        Thi Van Su NGAN
# 230       1768.941800            Naomi GIRMA
# 236       1731.840720             Julie ERTZ
# 256       1690.401592        Thi Kieu CHUONG
# 227       1605.802914          Alyssa NAEHER
# 271       1593.324288      Thi My Anh NGUYEN
# 234       1529.156796          Megan RAPINOE
# 263       1437.710816     Thi Kim Thanh TRAN
# 269       1397.537280      Thi Hai Linh TRAN
# 240       1374.754662           Rose LAVELLE
# 229       1231.906984              Emily FOX
# 246       1132.538048           Crystal DUNN
# ...
