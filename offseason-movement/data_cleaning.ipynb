# %%
import pandas as pd

# %%
league = "wnba"

# %%
# Read the rosters at the end of 2022
old = pd.read_csv(league + "/2022_end.csv")
old
# Out:
#     team             player
# 0     LV      Kierstan Bell
# 1     LV      Sydney Colson
# 2     LV       Chelsea Gray
# 3     LV      Dearica Hamby
# 4     LV  Theresa Plaisance
# ..   ...                ...
# 145  IND     Khayla Pointer
# 146  IND  Danielle Robinson
# 147  IND       Alanna Smith
# 148  IND      NaLyssa Smith
# 149  IND   Victoria Vivians
#
# [150 rows x 2 columns]

# %%
# Read the rosters at the beginning of 2023
new = pd.read_csv(league + "/2023_start.csv")
new
# Out:
#     team            player
# 0     LV     Kierstan Bell
# 1     LV      Alysha Clark
# 2     LV     Sydney Colson
# 3     LV      Cayla George
# 4     LV      Chelsea Gray
# ..   ...               ...
# 138  IND   Victaria Saxton
# 139  IND     NaLyssa Smith
# 140  IND  Victoria Vivians
# 141  IND    Kristy Wallace
# 142  IND     Erica Wheeler
#
# [143 rows x 2 columns]

# %%
# Join the rosters
df = (
    old.set_index("player")
    .join(new.set_index("player"), how="outer", lsuffix="_old", rsuffix="_new")
    .reset_index()
)
df
# Out:
#                player team_old team_new
# 0         A'ja Wilson       LV       LV
# 1             AD Durr      ATL      ATL
# 2       Aari McDonald      ATL      ATL
# 3       Aerial Powers      MIN      MIN
# 4      Aisha Sheppard       LV      NaN
# ..                ...      ...      ...
# 177   Veronica Burton      DAL      DAL
# 178   Victaria Saxton      NaN      IND
# 179  Victoria Vivians      IND      IND
# 180     Yvonne Turner      PHX      SEA
# 181         Zia Cooke      NaN       LA
#
# [182 rows x 3 columns]

# %%
# Find all the duplicate entries
pd.concat(g for _, g in df.groupby("player") if len(g) > 1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-45-492f6a9b4540> in <module>
#       1 # Find all the duplicate entries
# ----> 2 pd.concat(g for _, g in df.groupby("player") if len(g) > 1)
#
# ~/.local/lib/python3.8/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/.local/lib/python3.8/site-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     292     ValueError: Indexes have overlapping values: ['a']
#     293     """
# --> 294     op = _Concatenator(
#     295         objs,
#     296         axis=axis,
#
# ~/.local/lib/python3.8/site-packages/pandas/core/reshape/concat.py in __init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     349
#     350         if len(objs) == 0:
# --> 351             raise ValueError("No objects to concatenate")
#     352
#     353         if keys is None:
#
# ValueError: No objects to concatenate

# %%
# Check that all newly signed players are correct
signed = df[df["team_old"].isna()].sort_values("player")
signed.to_csv(league + "/signed.csv", index=False)
signed
# Out:
#                       player team_old team_new
# 6              Aliyah Boston      NaN      IND
# 11           Amanda Zahui B.      NaN      WSH
# 13          Arella Guirantes      NaN      SEA
# 16              Ashley Joens      NaN      DAL
# 20           Bernadett Határ      NaN      IND
# 28           Brittney Griner      NaN      PHX
# 31              Cayla George      NaN       LV
# 49            Diamond Miller      NaN      MIN
# 51              Dorka Juhász      NaN      MIN
# 52   Dulcy Fankam Mendjiadeu      NaN      SEA
# 63              Grace Berger      NaN      IND
# 64               Haley Jones      NaN      ATL
# 68              Ivana Dojkić      NaN      SEA
# 70            Jade Melbourne      NaN      SEA
# 81            Jordan Horston      NaN      SEA
# 85              Kadi Sissoko      NaN      PHX
# 96                 Kia Nurse      NaN      SEA
# 105         Laeticia Amihere      NaN      ATL
# 106               Lauren Cox      NaN     CONN
# 107        Layshia Clarendon      NaN       LA
# 108             Leigha Brown      NaN     CONN
# 111                  Li Meng      NaN      WSH
# 115       Lou Lopez-Sénéchal      NaN      DAL
# 116           Maddy Siegrist      NaN      DAL
# 125           Morgan Bertsch      NaN      CHI
# 139            Nyara Sabally      NaN       NY
# 150              Robyn Parks      NaN      CHI
# 160          Sheyenne Parker      NaN      ATL
# 161                Sika Koné      NaN      CHI
# 167               Sug Sutton      NaN      PHX
# 178          Victaria Saxton      NaN      IND
# 181                Zia Cooke      NaN       LA

# %%
# Check that all dropped players are correct
dropped = df[df["team_new"].isna()].sort_values("player")
dropped.to_csv(league + "/dropped.csv", index=False)
dropped
# Out:
#                   player team_old team_new
# 4         Aisha Sheppard       LV      NaN
# 7          Allie Quigley      CHI      NaN
# 12          Anneli Maley      CHI      NaN
# 19   Beatrice Mompremier      ATL      NaN
# 23          Bria Hartley     CONN      NaN
# 24        Briann January      SEA      NaN
# 32        Charli Collier      DAL      NaN
# 34       Chennedy Carter       LA      NaN
# 35       Cheyenne Parker      ATL      NaN
# 40        Damiris Dantas      MIN      NaN
# 45    Destanni Henderson      IND      NaN
# 46         DiDi Richards       NY      NaN
# 55        Emily Engstler      IND      NaN
# 57        Emma Meesseman      CHI      NaN
# 58      Epiphanny Prince      SEA      NaN
# 62        Gabby Williams      SEA      NaN
# 66         Iliana Rupert       LV      NaN
# 71       Jantel Lavender      SEA      NaN
# 74        Jasmine Walker       LA      NaN
# 75         Jazmine Jones      WSH      NaN
# 76          Jennie Simms      PHX      NaN
# 84        Julie Allemand      CHI      NaN
# 86           Kaela Davis      PHX      NaN
# 95        Khayla Pointer      IND      NaN
# 97            Kia Vaughn      ATL      NaN
# 99        Kiana Williams     CONN      NaN
# 100         Kianna Smith       LA      NaN
# 112             Li Yueru      CHI      NaN
# 121         Megan Walker      ATL      NaN
# 143          Rae Burrell       LA      NaN
# 146         Rennia Davis      IND      NaN
# 147        Reshanda Gray      PHX      NaN
# 151          Rui Machida      WSH      NaN
# 154           Sam Thomas      PHX      NaN
# 165     Stephanie Talbot      SEA      NaN
# 166             Sue Bird      SEA      NaN
# 169        Sylvia Fowles      MIN      NaN
# 171    Theresa Plaisance       LV      NaN
# 175         Tina Charles      SEA      NaN

# %%
# Write output to file
df.to_csv(league + "/2022_2023_movement.csv", index=False)
