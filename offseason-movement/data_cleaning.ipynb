# %%
import pandas as pd

# %%
league = "wnba"

# %%
# Read the rosters at the end of 2022
old = pd.read_csv(league + "/2022_end.csv")
old
# Out:
#     team             player
# 0     LV      Kierstan Bell
# 1     LV      Sydney Colson
# 2     LV       Chelsea Gray
# 3     LV      Dearica Hamby
# 4     LV  Theresa Plaisance
# ..   ...                ...
# 140  IND   Tiffany Mitchell
# 141  IND     Khayla Pointer
# 142  IND  Danielle Robinson
# 143  IND      NaLyssa Smith
# 144  IND   Victoria Vivians
#
# [145 rows x 2 columns]

# %%
# Read the rosters at the beginning of 2023
new = pd.read_csv(league + "/2023_start.csv")
new
# Out:
#     team            player
# 0     LV     Kierstan Bell
# 1     LV      Alysha Clark
# 2     LV     Sydney Colson
# 3     LV      Cayla George
# 4     LV      Chelsea Gray
# ..   ...               ...
# 138  IND   Victaria Saxton
# 139  IND     NaLyssa Smith
# 140  IND  Victoria Vivians
# 141  IND    Kristy Wallace
# 142  IND     Erica Wheeler
#
# [143 rows x 2 columns]

# %%
# Join the rosters
df = (
    old.set_index("player")
    .join(new.set_index("player"), how="outer", lsuffix="_old", rsuffix="_new")
    .reset_index()
)
df
# Out:
#                player team_old team_new
# 0         A'ja Wilson       LV       LV
# 1             AD Durr      ATL      ATL
# 2       Aari McDonald      ATL      ATL
# 3       Aerial Powers      MIN      MIN
# 4      Aisha Sheppard       LV      NaN
# ..                ...      ...      ...
# 174   Veronica Burton      DAL      DAL
# 175   Victaria Saxton      NaN      IND
# 176  Victoria Vivians      IND      IND
# 177     Yvonne Turner      PHX      SEA
# 178         Zia Cooke      NaN       LA
#
# [179 rows x 3 columns]

# %%
# Find all the duplicate entries
pd.concat(g for _, g in df.groupby("player") if len(g) > 1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 2
#       1 # Find all the duplicate entries
# ----> 2 pd.concat(g for _, g in df.groupby("player") if len(g) > 1)
#
# File ~/.local/lib/python3.10/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/reshape/concat.py:347, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     143 @deprecate_nonkeyword_arguments(version=None, allowed_args=["objs"])
#     144 def concat(
#     145     objs: Iterable[NDFrame] | Mapping[Hashable, NDFrame],
#    (...)
#     154     copy: bool = True,
#     155 ) -> DataFrame | Series:
#     156     """
#     157     Concatenate pandas objects along a particular axis with optional set logic
#     158     along the other axes.
#    (...)
#     345     ValueError: Indexes have overlapping values: ['a']
#     346     """
# --> 347     op = _Concatenator(
#     348         objs,
#     349         axis=axis,
#     350         ignore_index=ignore_index,
#     351         join=join,
#     352         keys=keys,
#     353         levels=levels,
#     354         names=names,
#     355         verify_integrity=verify_integrity,
#     356         copy=copy,
#     357         sort=sort,
#     358     )
#     360     return op.get_result()
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/reshape/concat.py:404, in _Concatenator.__init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     401     objs = list(objs)
#     403 if len(objs) == 0:
# --> 404     raise ValueError("No objects to concatenate")
#     406 if keys is None:
#     407     objs = list(com.not_none(*objs))
#
# ValueError: No objects to concatenate

# %%
# Check that all newly signed players are correct
signed = df[df["team_old"].isna()].sort_values("player")
signed.to_csv(league + "/signed.csv", index=False)
signed
# Out:
#                       player team_old team_new
# 5               Alanna Smith      NaN      CHI
# 6              Aliyah Boston      NaN      IND
# 11           Amanda Zahui B.      NaN      WSH
# 12          Arella Guirantes      NaN      SEA
# 15              Ashley Joens      NaN      DAL
# 19           Bernadett Határ      NaN      IND
# 27           Brittney Griner      NaN      PHX
# 30              Cayla George      NaN       LV
# 48            Diamond Miller      NaN      MIN
# 50              Dorka Juhász      NaN      MIN
# 51   Dulcy Fankam Mendjiadeu      NaN      SEA
# 62              Grace Berger      NaN      IND
# 63               Haley Jones      NaN      ATL
# 67              Ivana Dojkić      NaN      SEA
# 69            Jade Melbourne      NaN      SEA
# 80            Jordan Horston      NaN      SEA
# 84              Kadi Sissoko      NaN      PHX
# 95                 Kia Nurse      NaN      SEA
# 103         Laeticia Amihere      NaN      ATL
# 104               Lauren Cox      NaN     CONN
# 105        Layshia Clarendon      NaN       LA
# 106             Leigha Brown      NaN     CONN
# 109                  Li Meng      NaN      WSH
# 112             Lorela Cubaj      NaN      ATL
# 113       Lou Lopez-Sénéchal      NaN      DAL
# 114           Maddy Siegrist      NaN      DAL
# 122           Morgan Bertsch      NaN      CHI
# 134           Nikolina Milic      NaN      MIN
# 136            Nyara Sabally      NaN       NY
# 148              Robyn Parks      NaN      CHI
# 158                Sika Koné      NaN      CHI
# 164               Sug Sutton      NaN      PHX
# 175          Victaria Saxton      NaN      IND
# 178                Zia Cooke      NaN       LA

# %%
# Check that all dropped players are correct
dropped = df[df["team_new"].isna()].sort_values("player")
dropped.to_csv(league + "/dropped.csv", index=False)
dropped
# Out:
#                   player team_old team_new
# 4         Aisha Sheppard       LV      NaN
# 7          Allie Quigley      CHI      NaN
# 18   Beatrice Mompremier      ATL      NaN
# 22          Bria Hartley     CONN      NaN
# 23        Briann January      SEA      NaN
# 31        Charli Collier      DAL      NaN
# 33       Chennedy Carter       LA      NaN
# 39        Damiris Dantas      MIN      NaN
# 44    Destanni Henderson      IND      NaN
# 45         DiDi Richards       NY      NaN
# 54        Emily Engstler      IND      NaN
# 56        Emma Meesseman      CHI      NaN
# 57      Epiphanny Prince      SEA      NaN
# 61        Gabby Williams      SEA      NaN
# 65         Iliana Rupert       LV      NaN
# 70       Jantel Lavender      SEA      NaN
# 73        Jasmine Walker       LA      NaN
# 74         Jazmine Jones      WSH      NaN
# 75          Jennie Simms      PHX      NaN
# 83        Julie Allemand      CHI      NaN
# 85           Kaela Davis      PHX      NaN
# 94        Khayla Pointer      IND      NaN
# 96            Kia Vaughn      ATL      NaN
# 98          Kianna Smith       LA      NaN
# 110             Li Yueru      CHI      NaN
# 137         Odyssey Sims      CHI      NaN
# 141          Rae Burrell       LA      NaN
# 144         Rennia Davis      IND      NaN
# 145        Reshanda Gray      PHX      NaN
# 149          Rui Machida      WSH      NaN
# 152           Sam Thomas      PHX      NaN
# 162     Stephanie Talbot      SEA      NaN
# 163             Sue Bird      SEA      NaN
# 166        Sylvia Fowles      MIN      NaN
# 168    Theresa Plaisance       LV      NaN
# 172         Tina Charles      SEA      NaN

# %%
# Write output to file
df.to_csv(league + "/2022_2023_movement.csv", index=False)
