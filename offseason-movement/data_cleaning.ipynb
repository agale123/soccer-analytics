# %%
import pandas as pd

# %%
league = "nwsl"

# %%
# Read the rosters at the end of 2022
old = pd.read_csv(league + "/2022_end.csv")
old
# Out:
#     team             player
# 0    CHI      Alyssa Naeher
# 1    CHI    Amanda Kowalski
# 2    CHI        Arin Wright
# 3    CHI           Ava Cook
# 4    CHI  Bianca St-Georges
# ..   ...                ...
# 316  WAS          Sam Staab
# 317  WAS       Tara McKeown
# 318  WAS      Taylor Aylmer
# 319  WAS        Tori Huster
# 320  WAS     Trinity Rodman
#
# [321 rows x 2 columns]

# %%
# Read the rosters at the beginning of 2023
new = pd.read_csv(league + "/2023_start.csv")
new
# Out:
#     team           player
# 0    CHI     Addie McCain
# 1    CHI    Ally Schlegel
# 2    CHI    Alyssa Naeher
# 3    CHI  Amanda Kowalski
# 4    CHI      Arin Wright
# ..   ...              ...
# 308  WAS     Riley Tanner
# 309  WAS        Sam Staab
# 310  WAS     Tara McKeown
# 311  WAS      Tori Huster
# 312  WAS   Trinity Rodman
#
# [313 rows x 2 columns]

# %%
# Join the rosters
df = (
    old.set_index("player")
    .join(new.set_index("player"), how="outer", lsuffix="_old", rsuffix="_new")
    .reset_index()
)
df
# Out:
#               player team_old team_new
# 0    Abby Dahlkemper       SD       SD
# 1         Abby Erceg       NC      LOU
# 2         Abby Smith      POR      NJY
# 3       Addie McCain       KC      CHI
# 4    Addisyn Merrick       KC       KC
# ..               ...      ...      ...
# 372      Wang Shuang      LOU      LOU
# 373     Yazmeen Ryan      POR      NJY
# 374    Yuki Nagasato      CHI      CHI
# 375      Zaneta Wyne      LOU      LOU
# 376        Zoe Morse      CHI      NaN
#
# [377 rows x 3 columns]

# %%
# Check that all newly signed players are correct
signed = df[df["team_old"].isna()].sort_values("player")
signed.to_csv(league + "/signed.csv", index=False)
signed
# Out:
#                        player team_old team_new
# 5                     Adriana      NaN      ORL
# 11            Alexa Spaanstra      NaN       KC
# 17              Ally Schlegel      NaN      CHI
# 24            Alyssa Thompson      NaN       LA
# 30          Angelina Anderson      NaN       LA
# 35                 Ary Borges      NaN      LOU
# 54           Bárbara Olivieri      NaN      HOU
# 61               Carly Nelson      NaN      ORL
# 74            Cheyenne Shorts      NaN       SD
# 77             Chloe Ricketts      NaN      WAS
# 81            Civana Kuhlmann      NaN      WAS
# 84              Clara Robbins      NaN       NC
# 106           Elli Pikkujämsä      NaN      LOU
# 113              Emily Madril      NaN      ORL
# 124            Gabby Robinson      NaN       KC
# 125           Gabrielle Carle      NaN      WAS
# 128          Giovanna DeMarco      NaN       SD
# 132             Haley Hopkins      NaN       NC
# 134                Hanna Glas      NaN       KC
# 136             Havana Solaun      NaN      HOU
# 143              Inès Jaurena      NaN      WAS
# 144             Izzy D'Aquila      NaN      POR
# 155         Jenna Nighswonger      NaN      NJY
# 166          Jordan Silkowitz      NaN       KC
# 171             Julia Bianchi      NaN      CHI
# 176           Jyllissa Harris      NaN      HOU
# 189             Kayla Fischer      NaN      LOU
# 211            Lauren Brzykcy      NaN       SD
# 212              Lauren Kozal      NaN      POR
# 215               Lena Silano      NaN      WAS
# 219           Lindsi Jennings      NaN      HOU
# 221                     Luany      NaN      RGN
# 223           Lyza Bosselmann      NaN      WAS
# 225           Mackenzie Pluck      NaN       LA
# 227           Madelyn Desiano      NaN      HOU
# 237              Mandy Haught      NaN      NJY
# 253          Melanie Barcenas      NaN       SD
# 257            Messiah Bright      NaN      ORL
# 263           Michelle Cooper      NaN       KC
# 267         Mille Gejl Jensen      NaN       NC
# 269             Mimmi Larsson      NaN       KC
# 276              Narumi Miura      NaN       NC
# 284            Nicole Douglas      NaN      WAS
# 289            Olivia Wingate      NaN       NC
# 290             Paige Metayer      NaN      WAS
# 296          Penelope Hocking      NaN      CHI
# 304              Riley Parker      NaN      LOU
# 305              Riley Tanner      NaN      WAS
# 310            Rylan Childers      NaN       KC
# 327               Sierra Enge      NaN       SD
# 333              Sophie Hirst      NaN      HOU
# 334              Sophie Jones      NaN      CHI
# 337              Summer Yates      NaN      ORL
# 338  Svava Rós Guðmundsdóttir      NaN      NJY
# 339            Sydney Collins      NaN       NC
# 365              Uchenna Kanu      NaN      LOU

# %%
# Check that all dropped players are correct
dropped = df[df["team_new"].isna()].sort_values("player")
dropped.to_csv(league + "/dropped.csv", index=False)
dropped
# Out:
#                 player team_old team_new
# 14         Alia Martin      WAS      NaN
# 21       Almuth Schult       LA      NaN
# 38       Ashlyn Harris      NJY      NaN
# 40      Audrey Harding      WAS      NaN
# 42      Averie Collins      WAS      NaN
# ..                 ...      ...      ...
# 358  Tiernny Wiltshire      HOU      NaN
# 359        Tobin Heath      RGN      NaN
# 360      Toni Pressley      ORL      NaN
# 366     Valérie Gauvin      HOU      NaN
# 376          Zoe Morse      CHI      NaN
#
# [64 rows x 3 columns]

# %%
# Write output to file
df.to_csv(league + "/2022_2023_movement.csv", index=False)
