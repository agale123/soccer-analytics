# %%
from common import plot_standings, FAWSL
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("22_23_rank_by_week.csv", index_col=0)
df
# Out:
#      2022/9/19  2022/9/26  2022/10/3  2022/10/17  2022/10/24  2022/10/31  \
# ARS          1          1          1           2           1           2
# AST          3          3          3           4           7           8
# BHA         11          8          7          10          10          11
# CHE          8          5          4           3           3           3
# EVE         10          4          5           5           4           6
# LEI          9         11         11          12          12          12
# LIV          4          7          6           9           9          10
# MNC          7         10         10           8           6           4
# MNU          2          2          2           1           2           1
# REA         12         12         12          11          11           9
# TOT          5          9          8           7           8           5
# WHU          6          6          9           6           5           7
#
# ...

# %%
df.columns = [str(x) for x in range(1, len(df.columns) + 1)]

# %%
plot_standings(
    df,
    folder="images",
    playoff_cutoff=None,
    names=FAWSL.NAMES,
    colors=FAWSL.COLORS,
    text_colors=FAWSL.TEXT_COLORS,
    title="FAWSL 22-23 Standings",
    extra_cols=4,
)
