# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import constants

# %%
points = pd.read_csv("points_by_week.csv", index_col=0)
games = pd.read_csv("games_by_week.csv", index_col=0)

# %%
df = points/games

# %%
# Sort so top teams have lines drawn on top
week = 16
df = df.sort_values(by=[str(week)], ascending=True)
df
# Out:
#         1    2         3     4         5         6         7         8  \
# NJNY  3.0  1.5  1.500000  1.00  1.500000  1.800000  1.500000  1.285714
# WAS   3.0  3.0  1.500000  1.25  1.200000  1.000000  0.888889  0.900000
# LOU   0.0  0.5  0.666667  1.60  1.333333  1.142857  1.000000  1.000000
# NC    0.0  0.0  0.000000  0.00  0.250000  0.800000  1.166667  1.000000
# ORL   0.0  1.5  1.333333  1.40  1.333333  1.142857  1.000000  0.888889
# CHI   3.0  3.0  1.500000  2.00  1.750000  1.833333  1.875000  1.777778
# LA    3.0  1.5  2.000000  2.25  1.800000  1.000000  1.625000  1.444444
# RGN   0.0  0.5  0.666667  0.75  1.500000  1.285714  1.250000  1.444444
# HOU   0.0  1.5  1.333333  1.75  1.600000  1.833333  1.500000  1.666667
# POR   3.0  3.0  2.000000  1.25  1.200000  1.500000  1.625000  1.777778
# KC    0.0  0.0  0.333333  0.25  0.666667  0.714286  1.000000  1.000000
# SD    3.0  3.0  3.000000  2.40  2.000000  1.857143  1.666667  1.800000
#
#              9        10        11        12        13        14        15  \
# NJNY  1.125000  1.333333  1.200000  1.090909  1.000000  0.923077  0.800000
# WAS   0.818182  0.750000  0.769231  0.785714  0.800000  0.750000  0.750000
# LOU   1.000000  0.909091  0.916667  0.846154  0.866667  0.875000  0.875000
# NC    0.875000  0.888889  0.888889  0.900000  0.909091  0.833333  1.000000
# ORL   0.900000  1.090909  1.083333  1.076923  1.071429  1.200000  1.312500
# CHI   1.900000  1.818182  1.666667  1.538462  1.642857  1.533333  1.437500
# LA    1.400000  1.545455  1.545455  1.416667  1.384615  1.500000  1.466667
# RGN   1.600000  1.545455  1.416667  1.538462  1.400000  1.500000  1.500000
# HOU   1.500000  1.363636  1.500000  1.615385  1.714286  1.666667  1.647059
# POR   1.700000  1.636364  1.750000  1.846154  1.785714  1.866667  1.866667
# KC    1.200000  1.363636  1.500000  1.461538  1.571429  1.666667  1.625000
# SD    1.909091  1.750000  1.692308  1.785714  1.666667  1.562500  1.647059
#
#             16
# NJNY  0.750000
# WAS   0.764706
# LOU   0.823529
# NC    1.066667
# ORL   1.235294
# CHI   1.529412
# LA    1.562500
# RGN   1.588235
# HOU   1.611111
# POR   1.647059
# KC    1.705882
# SD    1.722222

# %%
barlow = fm.FontProperties(fname="/home/agale/nwsl-analytics/nwsl-rank/Barlow.otf")
plt.rcParams["figure.figsize"] = (24, 13.5)
plt.figure(dpi=1200)
fig, ax = plt.subplots()

for team in df.index:
    ax.plot(
        df.columns,
        df.loc[team],
        linewidth=10,
        color=constants.colors[team],
        alpha=0.9,
        solid_capstyle="round",
    )
