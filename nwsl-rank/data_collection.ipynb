# %%
import requests
import json
import pandas as pd
from common import NWSL

# %%
# May 27
week = 10
year = 2024

# %%
data = requests.get("https://nwsl-api-prd-sdp.akamaized.net/v1/nwsl/football/seasons/nwsl::Football_Season::fe17bea0b7234cf7957c7249cb828270/standings?locale=en-US&orderBy=rank&direction=asc").json()
data
# Out:
# {'competition': {'seasonId': 'nwsl::Football_Season::fe17bea0b7234cf7957c7249cb828270',
#   'startDateUtc': None,
#   'endDateUtc': None,
#   'seasonName': '2024',
#   'competitionId': 'nwsl::Football_Competition::3293333447504e83986ec13e794b68ea',
#   'providerId': '',
#   'name': 'NWSL',
#   'officialName': 'NWSL',
#   'shortName': 'NWSL',
#   'acronymName': 'NWSL'},
#  'type': 'table',
#  'teams': [{'stats': [{'statsId': 'rank',
#      'statsLabel': 'Rank',
#      'statsLabelAbbreviation': 'Rank',
#      'statsValue': 1,
#      'statsUnit': None,
#      'statsUnitAbbreviation': None},
#     {'statsId': 'team',
#      'statsLabel': 'Club',
#      'statsLabelAbbreviation': 'Club',
#      'statsValue': None,
#      'statsUnit': None,
#      'statsUnitAbbreviation': None},
#     {'statsId': 'points',
#      'statsLabel': 'Points',
#      'statsLabelAbbreviation': 'PTS',
#      'statsValue': 27,
#      'statsUnit': None,
#      'statsUnitAbbreviation': None},
#     {'statsId': 'matches-played',
#      'statsLabel': 'Matches played',
#      'statsLabelAbbreviation': 'P',
#      'statsValue': 11,
#      'statsUnit': None,
#      'statsUnitAbbreviation': None},
#     {'statsId': 'win',
#      'statsLabel': 'Win',
#      'statsLabelAbbreviation': 'W',
#      'statsValue': 8,
#      'statsUnit': None,
#      'statsUnitAbbreviation': None},
#     {'statsId': 'draw',
#      'statsLabel': 'Draw',
#      'statsLabelAbbreviation': 'D',
#      'statsValue': 3,
#      'statsUnit': None,
#      'statsUnitAbbreviation': None},
#     {'statsId': 'lose',
#      'statsLabel': 'Lose',
#      'statsLabelAbbreviation': 'L',
#      'statsValue': 0,
#      'statsUnit': None,
#      'statsUnitAbbreviation': None},
#     {'statsId': 'goals-for',
#      'statsLabel': 'Goals for',
#      'statsLabelAbbreviation': 'GF',
#      'statsValue': 20,
#      'statsUnit': None,
#      'statsUnitAbbreviation': None},
#     {'statsId': 'goals-against',
#      'statsLabel': 'Goals against',
#      'statsLabelAbbreviation': 'GA',
#      'statsValue': 10,
#      'statsUnit': None,
#      'statsUnitAbbreviation': None},
#     {'statsId': 'goal-difference',
#      'statsLabel': 'Goal difference',
#      'statsLabelAbbreviation': 'GD',
#      'statsValue': 10,
#      'statsUnit': None,
#      'statsUnitAbbreviation': None},
#     {'statsId': 'movement',
#      'statsLabel': 'Movement',
#      'statsLabelAbbreviation': 'Movement',
#      'statsValue': 'stable',
#      'statsUnit': None,
#      'statsUnitAbbreviation': None},
#     {'statsId': 'form',
#      'statsLabel': 'Form',
#      'statsLabelAbbreviation': 'Form',
#      'statsValue': [{'formLabel': 'Win',
#        'formLabelAbbreviation': 'W',
#        'formType': 'W'},
#       {'formLabel': 'Win', 'formLabelAbbreviation': 'W', 'formType': 'W'},
#       {'formLabel': 'Win', 'formLabelAbbreviation': 'W', 'formType': 'W'},
#       {'formLabel': 'Win', 'formLabelAbbreviation': 'W', 'formType': 'W'},
#       {'formLabel': 'Win', 'formLabelAbbreviation': 'W', 'formType': 'W'},
#       {'formLabel': 'Win', 'formLabelAbbreviation': 'W', 'formType': 'W'}],
#      'statsUnit': None,
#      'statsUnitAbbreviation': None}],
#    'qualification': None,
#    'teamId': 'nwsl::Football_Team::c3e9513e280b41e5bfbb8230076e8c43',
#    'providerId': 'opta:Team:966pdxhsoxaib9qt5083h8uus',
#    'shortName': 'Pride',
#    'officialName': 'Orlando Pride',
#    'acronymName': 'ORL',
#    'mediaName': 'Pride',
#    'mediaShortName': 'Pride'},
#   {'stats': [{'statsId': 'rank',
#      'statsLabel': 'Rank',
#      'statsLabelAbbreviation': 'Rank',
#      'statsValue': 2,
#      'statsUnit': None,
#      'statsUnitAbbreviation': None},
#     {'statsId': 'team',
#      'statsLabel': 'Club',
#      'statsLabelAbbreviation': 'Club',
#      'statsValue': None,
#      'statsUnit': None,
#      'statsUnitAbbreviation': None},
#     {'statsId': 'points',
#      'statsLabel': 'Points',
#      'statsLabelAbbreviation': 'PTS',
#      'statsValue': 25,
#      'statsUnit': None,
#      'statsUnitAbbreviation': None},
#     {'statsId': 'matches-played',
#      'statsLabel': 'Matches played',
#      'statsLabelAbbreviation': 'P',
#      'statsValue': 11,
#      'statsUnit': None,
#      'statsUnitAbbreviation': None},
#     {'statsId': 'win',
#      'statsLabel': 'Win',
#      'statsLabelAbbreviation': 'W',
#      'statsValue': 7,
#      'statsUnit': None,
#      'statsUnitAbbreviation': None},
#     {'statsId': 'draw',
#      'statsLabel': 'Draw',
#      'statsLabelAbbreviation': 'D',
#      'statsValue': 4,
#      'statsUnit': None,
#      'statsUnitAbbreviation': None},
#     {'statsId': 'lose',
#      'statsLabel': 'Lose',
#      'statsLabelAbbreviation': 'L',
#      'statsValue': 0,
#      'statsUnit': None,
#      'statsUnitAbbreviation': None},
#     {'statsId': 'goals-for',
#      'statsLabel': 'Goals for',
#      'statsLabelAbbreviation': 'GF',
#      'statsValue': 26,
#      'statsUnit': None,
#      'statsUnitAbbreviation': None},
#     {'statsId': 'goals-against',
#      'statsLabel': 'Goals against',
#      'statsLabelAbbreviation': 'GA',
#      'statsValue': 15,
#      'statsUnit': None,
#      'statsUnitAbbreviation': None},
#     {'statsId': 'goal-difference',
#      'statsLabel': 'Goal difference',
#      'statsLabelAbbreviation': 'GD',
#      'statsValue': 11,
#      'statsUnit': None,
#      'statsUnitAbbreviation': None},
#     {'statsId': 'movement',
#      'statsLabel': 'Movement',
#      'statsLabelAbbreviation': 'Movement',
#      'statsValue': 'stable',
#      'statsUnit': None,
#      'statsUnitAbbreviation': None},
#     {'statsId': 'form',
#      'statsLabel': 'Form',
#      'statsLabelAbbreviation': 'Form',
#      'statsValue': [{'formLabel': 'Win',
#        'formLabelAbbreviation': 'W',
#        'formType': 'W'},
#       {'formLabel': 'Draw', 'formLabelAbbreviation': 'D', 'formType': 'D'},
#       {'formLabel': 'Win', 'formLabelAbbreviation': 'W', 'formType': 'W'},
#       {'formLabel': 'Draw', 'formLabelAbbreviation': 'D', 'formType': 'D'},
#       {'formLabel': 'Draw', 'formLabelAbbreviation': 'D', 'formType': 'D'},
#       {'formLabel': 'Win', 'formLabelAbbreviation': 'W', 'formType': 'W'}],
#      'statsUnit': None,
#      'statsUnitAbbreviation': None}],
#    'qualification': None,
#    'teamId': 'nwsl::Football_Team::2c1699409ff84c9eb491aeaca3d3edde',
#    'providerId': 'opta:Team:agxipc0vk4rtg09amjxv10nx0',
#    'shortName': 'KC Current',
#    'officialName': 'Kansas City Current',
#    'acronymName': 'KC',
#    'mediaName': 'KC Current',
#    'mediaShortName': 'KC Current'},
#   {'stats': [{'statsId': 'rank',
#      'statsLabel': 'Rank',
#      'statsLabelAbbreviation': 'Rank',
#      'statsValue': 3,
#      'statsUnit': None,
#      'statsUnitAbbreviation': None},
#     {'statsId': 'team',
#      'statsLabel': 'Club',
#      'statsLabelAbbreviation': 'Club',
#      'statsValue': None,
#      'statsUnit': None,
#      'statsUnitAbbreviation': None},
#     {'statsId': 'points',
#      'statsLabel': 'Points',
#      'statsLabelAbbreviation': 'PTS',
#      'statsValue': 24,
#      'statsUnit': None,
#      'statsUnitAbbreviation': None},
#     {'statsId': 'matches-played',
#      'statsLabel': 'Matches played',
#      'statsLabelAbbreviation': 'P',
#      'statsValue': 11,
#      'statsUnit': None,
#      'statsUnitAbbreviation': None},
#     {'statsId': 'win',
#      'statsLabel': 'Win',
#      'statsLabelAbbreviation': 'W',
#      'statsValue': 8,
#      'statsUnit': None,
#      'statsUnitAbbreviation': None},
#     {'statsId': 'draw',
#      'statsLabel': 'Draw',
#      'statsLabelAbbreviation': 'D',
#      'statsValue': 0,
#      'statsUnit': None,
#      'statsUnitAbbreviation': None},
#     {'statsId': 'lose',
#      'statsLabel': 'Lose',
#      'statsLabelAbbreviation': 'L',
#      'statsValue': 3,
#      'statsUnit': None,
#      'statsUnitAbbreviation': None},
#     {'statsId': 'goals-for',
#      'statsLabel': 'Goals for',
#      'statsLabelAbbreviation': 'GF',
#      'statsValue': 25,
#      'statsUnit': None,
#      'statsUnitAbbreviation': None},
#     {'statsId': 'goals-against',
#      'statsLabel': 'Goals against',
#      'statsLabelAbbreviation': 'GA',
#      'statsValue': 16,
#      'statsUnit': None,
#      'statsUnitAbbreviation': None},
#     {'statsId': 'goal-difference',
#      'statsLabel': 'Goal difference',
#      'statsLabelAbbreviation': 'GD',
#      'statsValue': 9,
#      'statsUnit': None,
#      'statsUnitAbbreviation': None},
#     {'statsId': 'movement',
#      'statsLabel': 'Movement',
#      'statsLabelAbbreviation': 'Movement',
#      'statsValue': 'stable',
#      'statsUnit': None,
#      'statsUnitAbbreviation': None},
#     {'statsId': 'form',
#      'statsLabel': 'Form',
#      'statsLabelAbbreviation': 'Form',
#      'statsValue': [{'formLabel': 'Win',
#        'formLabelAbbreviation': 'W',
#        'formType': 'W'},
#       {'formLabel': 'Win', 'formLabelAbbreviation': 'W', 'formType': 'W'},
#       {'formLabel': 'Win', 'formLabelAbbreviation': 'W', 'formType': 'W'},
#       {'formLabel': 'Lose', 'formLabelAbbreviation': 'L', 'formType': 'L'},
#       {'formLabel': 'Win', 'formLabelAbbreviation': 'W', 'formType': 'W'},
#       {'formLabel': 'Lose', 'formLabelAbbreviation': 'L', 'formType': 'L'}],
#      'statsUnit': None,
#      'statsUnitAbbreviation': None}],
#    'qualification': None,
#    'teamId': 'nwsl::Football_Team::c31d72afc09f42ee86418633aa41390a',
#    'providerId': 'opta:Team:f1ks82wpiewyqs6h3oz9v4hzj',
#    'shortName': 'Spirit',
#    'officialName': 'Washington Spirit',
#    'acronymName': 'WAS',
#    'mediaName': 'Spirit',
#    'mediaShortName': 'Spirit'},
#   {'stats': [{'statsId': 'rank',
#      'statsLabel': 'Rank',
#      'statsLabelAbbreviation': 'Rank',
#      'statsValue': 4,
#      'statsUnit': None,
#      'statsUnitAbbreviation': None},
#     {'statsId': 'team',
#      'statsLabel': 'Club',
#      'statsLabelAbbreviation': 'Club',
#      'statsValue': None,
#      'statsUnit': None,
#      'statsUnitAbbreviation': None},
#     {'statsId': 'points',
#      'statsLabel': 'Points',
#      'statsLabelAbbreviation': 'PTS',
#      'statsValue': 19,
#      'statsUnit': None,
#      'statsUnitAbbreviation': None},
#     {'statsId': 'matches-played',
#      'statsLabel': 'Matches played',
#      'statsLabelAbbreviation': 'P',
#      'statsValue': 11,
#      'statsUnit': None,
#      'statsUnitAbbreviation': None},
#     {'statsId': 'win',
#      'statsLabel': 'Win',
#      'statsLabelAbbreviation': 'W',
#      'statsValue': 6,
#      'statsUnit': None,
#      'statsUnitAbbreviation': None},
#     {'statsId': 'draw',
#      'statsLabel': 'Draw',
#      'statsLabelAbbreviation': 'D',
#      'statsValue': 1,
#      'statsUnit': None,
#      'statsUnitAbbreviation': None},
#     {'statsId': 'lose',
#      'statsLabel': 'Lose',
#      'statsLabelAbbreviation': 'L',
#      'statsValue': 4,
#      'statsUnit': None,
#      'statsUnitAbbreviation': None},
#     {'statsId': 'goals-for',
#      'statsLabel': 'Goals for',
#      'statsLabelAbbreviation': 'GF',
#      'statsValue': 24,
#      'statsUnit': None,
#      'statsUnitAbbreviation': None},
#     {'statsId': 'goals-against',
#      'statsLabel': 'Goals against',
#      'statsLabelAbbreviation': 'GA',
#      'statsValue': 16,
#      'statsUnit': None,
#      'statsUnitAbbreviation': None},
#     {'statsId': 'goal-difference',
#      'statsLabel': 'Goal difference',
#      'statsLabelAbbreviation': 'GD',
#      'statsValue': 8,
#      'statsUnit': None,
#      'statsUnitAbbreviation': None},
#     {'statsId': 'movement',
#      'statsLabel': 'Movement',
#      'statsLabelAbbreviation': 'Movement',
#      'statsValue': 'stable',
#      'statsUnit': None,
#      'statsUnitAbbreviation': None},
#     {'statsId': 'form',
#      'statsLabel': 'Form',
#      'statsLabelAbbreviation': 'Form',
#      'statsValue': [{'formLabel': 'Lose',
#        'formLabelAbbreviation': 'L',
#        'formType': 'L'},
#       {'formLabel': 'Win', 'formLabelAbbreviation': 'W', 'formType': 'W'},
#       {'formLabel': 'Win', 'formLabelAbbreviation': 'W', 'formType': 'W'},
#       {'formLabel': 'Win', 'formLabelAbbreviation': 'W', 'formType': 'W'},
#       {'formLabel': 'Win', 'formLabelAbbreviation': 'W', 'formType': 'W'},
#       {'formLabel': 'Win', 'formLabelAbbreviation': 'W', 'formType': 'W'}],
#      'statsUnit': None,
#      'statsUnitAbbreviation': None}],
#    'qualification': None,
#    'teamId': 'nwsl::Football_Team::96ba7b37bd8544a1a7329183459150ff',
#    'providerId': 'opta:Team:446mp88j1vpk9iwui9fiifrp8',
#    'shortName': 'Thorns',
#    'officialName': 'Portland Thorns',
#    'acronymName': 'POR',
#    'mediaName': 'Thorns',
#    'mediaShortName': 'Thorns'},
#   {'stats': [{'statsId': 'rank',
#      'statsLabel': 'Rank',
#      'statsLabelAbbreviation': 'Rank',
#      'statsValue': 5,
#      'statsUnit': None,
#      'statsUnitAbbreviation': None},
#     {'statsId': 'team',
#      'statsLabel': 'Club',
#      'statsLabelAbbreviation': 'Club',
#      'statsValue': None,
#      'statsUnit': None,
#      'statsUnitAbbreviation': None},
#     {'statsId': 'points',
#      'statsLabel': 'Points',
#      'statsLabelAbbreviation': 'PTS',
#      'statsValue': 18,
#      'statsUnit': None,
#      'statsUnitAbbreviation': None},
#     {'statsId': 'matches-played',
#      'statsLabel': 'Matches played',
#      'statsLabelAbbreviation': 'P',
#      'statsValue': 10,
#      'statsUnit': None,
#      'statsUnitAbbreviation': None},
#     {'statsId': 'win',
#      'statsLabel': 'Win',
#      'statsLabelAbbreviation': 'W',
#      'statsValue': 5,
#      'statsUnit': None,
#      'statsUnitAbbreviation': None},
#     {'statsId': 'draw',
#      'statsLabel': 'Draw',
#      'statsLabelAbbreviation': 'D',
#      'statsValue': 3,
#      'statsUnit': None,
#      'statsUnitAbbreviation': None},
#     {'statsId': 'lose',
#      'statsLabel': 'Lose',
#      'statsLabelAbbreviation': 'L',
#      'statsValue': 2,
#      'statsUnit': None,
#      'statsUnitAbbreviation': None},
#     {'statsId': 'goals-for',
#      'statsLabel': 'Goals for',
#      'statsLabelAbbreviation': 'GF',
#      'statsValue': 10,
#      'statsUnit': None,
#      'statsUnitAbbreviation': None},
#     {'statsId': 'goals-against',
#      'statsLabel': 'Goals against',
#      'statsLabelAbbreviation': 'GA',
#      'statsValue': 7,
#      'statsUnit': None,
#      'statsUnitAbbreviation': None},
#     {'statsId': 'goal-difference',
#      'statsLabel': 'Goal difference',
#      'statsLabelAbbreviation': 'GD',
#      'statsValue': 3,
#      'statsUnit': None,
#      'statsUnitAbbreviation': None},
#     {'statsId': 'movement',
#      'statsLabel': 'Movement',
#      'statsLabelAbbreviation': 'Movement',
#      'statsValue': 'up',
#      'statsUnit': None,
#      'statsUnitAbbreviation': None},
#     {'statsId': 'form',
#      'statsLabel': 'Form',
#      'statsLabelAbbreviation': 'Form',
#      'statsValue': [{'formLabel': 'Win',
#        'formLabelAbbreviation': 'W',
#        'formType': 'W'},
#       {'formLabel': 'Win', 'formLabelAbbreviation': 'W', 'formType': 'W'},
#       {'formLabel': 'Draw', 'formLabelAbbreviation': 'D', 'formType': 'D'},
#       {'formLabel': 'Win', 'formLabelAbbreviation': 'W', 'formType': 'W'},
#       {'formLabel': 'Win', 'formLabelAbbreviation': 'W', 'formType': 'W'},
#       {'formLabel': 'Draw', 'formLabelAbbreviation': 'D', 'formType': 'D'}],
#      'statsUnit': None,
#      'statsUnitAbbreviation': None}],
#    'qualification': None,
#    'teamId': 'nwsl::Football_Team::c83f2ca05aa84c738b5373f0d2a31b39',
#    'providerId': 'opta:Team:bgkfdckqfqnfbmecbtz03n76d',
#    'shortName': 'Gotham FC',
#    'officialName': 'NJ/NY Gotham FC',
#    'acronymName': 'NJY',
#    'mediaName': 'Gotham FC',
#    'mediaShortName': 'Gotham FC'},
#   {'stats': [{'statsId': 'rank',
#      'statsLabel': 'Rank',
#      'statsLabelAbbreviation': 'Rank',
#      'statsValue': 6,
#      'statsUnit': None,
#      'statsUnitAbbreviation': None},
#     {'statsId': 'team',
#      'statsLabel': 'Club',
#      'statsLabelAbbreviation': 'Club',
#      'statsValue': None,
#      'statsUnit': None,
#      'statsUnitAbbreviation': None},
#     {'statsId': 'points',
#      'statsLabel': 'Points',
#      'statsLabelAbbreviation': 'PTS',
#      'statsValue': 16,
#      'statsUnit': None,
#      'statsUnitAbbreviation': None},
#     {'statsId': 'matches-played',
#      'statsLabel': 'Matches played',
#      'statsLabelAbbreviation': 'P',
#      'statsValue': 11,
#      'statsUnit': None,
#      'statsUnitAbbreviation': None},
#     {'statsId': 'win',
#      'statsLabel': 'Win',
#      'statsLabelAbbreviation': 'W',
#      'statsValue': 5,
#      'statsUnit': None,
#      'statsUnitAbbreviation': None},
#     {'statsId': 'draw',
#      'statsLabel': 'Draw',
#      'statsLabelAbbreviation': 'D',
#      'statsValue': 1,
#      'statsUnit': None,
#      'statsUnitAbbreviation': None},
#     {'statsId': 'lose',
#      'statsLabel': 'Lose',
#      'statsLabelAbbreviation': 'L',
#      'statsValue': 5,
#      'statsUnit': None,
#      'statsUnitAbbreviation': None},
#     {'statsId': 'goals-for',
#      'statsLabel': 'Goals for',
#      'statsLabelAbbreviation': 'GF',
#      'statsValue': 15,
#      'statsUnit': None,
#      'statsUnitAbbreviation': None},
#     {'statsId': 'goals-against',
#      'statsLabel': 'Goals against',
#      'statsLabelAbbreviation': 'GA',
#      'statsValue': 15,
#      'statsUnit': None,
#      'statsUnitAbbreviation': None},
#     {'statsId': 'goal-difference',
#      'statsLabel': 'Goal difference',
#      'statsLabelAbbreviation': 'GD',
#      'statsValue': 0,
#      'statsUnit': None,
#      'statsUnitAbbreviation': None},
#     {'statsId': 'movement',
#      'statsLabel': 'Movement',
#      'statsLabelAbbreviation': 'Movement',
#      'statsValue': 'down',
#      'statsUnit': None,
#      'statsUnitAbbreviation': None},
#     {'statsId': 'form',
#      'statsLabel': 'Form',
#      'statsLabelAbbreviation': 'Form',
#      'statsValue': [{'formLabel': 'Lose',
#        'formLabelAbbreviation': 'L',
#        'formType': 'L'},
#       {'formLabel': 'Lose', 'formLabelAbbreviation': 'L', 'formType': 'L'},
#       {'formLabel': 'Win', 'formLabelAbbreviation': 'W', 'formType': 'W'},
#       {'formLabel': 'Win', 'formLabelAbbreviation': 'W', 'formType': 'W'},
#       {'formLabel': 'Lose', 'formLabelAbbreviation': 'L', 'formType': 'L'},
#       {'formLabel': 'Lose', 'formLabelAbbreviation': 'L', 'formType': 'L'}],
#      'statsUnit': None,
#      'statsUnitAbbreviation': None}],
#    'qualification': None,
#    'teamId': 'nwsl::Football_Team::269e825b853f4b43a9d38390aa92bf6e',
#    'providerId': 'opta:Team:dzxypx8djih58p668surbi4qm',
#    'shortName': 'Red Stars',
#    'officialName': 'Chicago Red Stars',
#    'acronymName': 'CHI',
#    'mediaName': 'Red Stars',
#    'mediaShortName': 'Red Stars'},
#   {'stats': [{'statsId': 'rank',
#      'statsLabel': 'Rank',
#      'statsLabelAbbreviation': 'Rank',
#      'statsValue': 7,
#      'statsUnit': None,
#      'statsUnitAbbreviation': None},
#     {'statsId': 'team',
#      'statsLabel': 'Club',
#      'statsLabelAbbreviation': 'Club',
#      'statsValue': None,
#      'statsUnit': None,
#      'statsUnitAbbreviation': None},
#     {'statsId': 'points',
#      'statsLabel': 'Points',
#      'statsLabelAbbreviation': 'PTS',
#      'statsValue': 15,
#      'statsUnit': None,
#      'statsUnitAbbreviation': None},
#     {'statsId': 'matches-played',
#      'statsLabel': 'Matches played',
#      'statsLabelAbbreviation': 'P',
#      'statsValue': 11,
#      'statsUnit': None,
#      'statsUnitAbbreviation': None},
#     {'statsId': 'win',
#      'statsLabel': 'Win',
#      'statsLabelAbbreviation': 'W',
#      'statsValue': 5,
#      'statsUnit': None,
#      'statsUnitAbbreviation': None},
#     {'statsId': 'draw',
#      'statsLabel': 'Draw',
#      'statsLabelAbbreviation': 'D',
#      'statsValue': 0,
#      'statsUnit': None,
#      'statsUnitAbbreviation': None},
#     {'statsId': 'lose',
#      'statsLabel': 'Lose',
#      'statsLabelAbbreviation': 'L',
#      'statsValue': 6,
#      'statsUnit': None,
#      'statsUnitAbbreviation': None},
#     {'statsId': 'goals-for',
#      'statsLabel': 'Goals for',
#      'statsLabelAbbreviation': 'GF',
#      'statsValue': 13,
#      'statsUnit': None,
#      'statsUnitAbbreviation': None},
#     {'statsId': 'goals-against',
#      'statsLabel': 'Goals against',
#      'statsLabelAbbreviation': 'GA',
#      'statsValue': 14,
#      'statsUnit': None,
#      'statsUnitAbbreviation': None},
#     {'statsId': 'goal-difference',
#      'statsLabel': 'Goal difference',
#      'statsLabelAbbreviation': 'GD',
#      'statsValue': -1,
#      'statsUnit': None,
#      'statsUnitAbbreviation': None},
#     {'statsId': 'movement',
#      'statsLabel': 'Movement',
#      'statsLabelAbbreviation': 'Movement',
#      'statsValue': 'down',
#      'statsUnit': None,
#      'statsUnitAbbreviation': None},
#     {'statsId': 'form',
#      'statsLabel': 'Form',
#      'statsLabelAbbreviation': 'Form',
#      'statsValue': [{'formLabel': 'Lose',
#        'formLabelAbbreviation': 'L',
#        'formType': 'L'},
#       {'formLabel': 'Win', 'formLabelAbbreviation': 'W', 'formType': 'W'},
#       {'formLabel': 'Lose', 'formLabelAbbreviation': 'L', 'formType': 'L'},
#       {'formLabel': 'Lose', 'formLabelAbbreviation': 'L', 'formType': 'L'},
#       {'formLabel': 'Lose', 'formLabelAbbreviation': 'L', 'formType': 'L'},
#       {'formLabel': 'Win', 'formLabelAbbreviation': 'W', 'formType': 'W'}],
#      'statsUnit': None,
#      'statsUnitAbbreviation': None}],
#    'qualification': None,
#    'teamId': 'nwsl::Football_Team::fb41ef4439dd495098cb6d40415767cc',
#    'providerId': 'opta:Team:b4fbmos00gxtk8qnaqsm392p5',
#    'shortName': 'Courage',
#    'officialName': 'North Carolina Courage',
#    'acronymName': 'NC',
#    'mediaName': 'Courage',
#    'mediaShortName': 'Courage'},
#   {'stats': [{'statsId': 'rank',
#      'statsLabel': 'Rank',
#      'statsLabelAbbreviation': 'Rank',
#      'statsValue': 8,
#      'statsUnit': None,
#      'statsUnitAbbreviation': None},
#     {'statsId': 'team',
#      'statsLabel': 'Club',
#      'statsLabelAbbreviation': 'Club',
#      'statsValue': None,
#      'statsUnit': None,
#      'statsUnitAbbreviation': None},
#     {'statsId': 'points',
#      'statsLabel': 'Points',
#      'statsLabelAbbreviation': 'PTS',
#      'statsValue': 12,
#      'statsUnit': None,
#      'statsUnitAbbreviation': None},
#     {'statsId': 'matches-played',
#      'statsLabel': 'Matches played',
#      'statsLabelAbbreviation': 'P',
#      'statsValue': 10,
#      'statsUnit': None,
#      'statsUnitAbbreviation': None},
#     {'statsId': 'win',
#      'statsLabel': 'Win',
#      'statsLabelAbbreviation': 'W',
#      'statsValue': 2,
#      'statsUnit': None,
#      'statsUnitAbbreviation': None},
#     {'statsId': 'draw',
#      'statsLabel': 'Draw',
#      'statsLabelAbbreviation': 'D',
#      'statsValue': 6,
#      'statsUnit': None,
#      'statsUnitAbbreviation': None},
#     {'statsId': 'lose',
#      'statsLabel': 'Lose',
#      'statsLabelAbbreviation': 'L',
#      'statsValue': 2,
#      'statsUnit': None,
#      'statsUnitAbbreviation': None},
#     {'statsId': 'goals-for',
#      'statsLabel': 'Goals for',
#      'statsLabelAbbreviation': 'GF',
#      'statsValue': 15,
#      'statsUnit': None,
#      'statsUnitAbbreviation': None},
#     {'statsId': 'goals-against',
#      'statsLabel': 'Goals against',
#      'statsLabelAbbreviation': 'GA',
#      'statsValue': 12,
#      'statsUnit': None,
#      'statsUnitAbbreviation': None},
#     {'statsId': 'goal-difference',
#      'statsLabel': 'Goal difference',
#      'statsLabelAbbreviation': 'GD',
#      'statsValue': 3,
#      'statsUnit': None,
#      'statsUnitAbbreviation': None},
#     {'statsId': 'movement',
#      'statsLabel': 'Movement',
#      'statsLabelAbbreviation': 'Movement',
#      'statsValue': 'up',
#      'statsUnit': None,
#      'statsUnitAbbreviation': None},
#     {'statsId': 'form',
#      'statsLabel': 'Form',
#      'statsLabelAbbreviation': 'Form',
#      'statsValue': [{'formLabel': 'Win',
#        'formLabelAbbreviation': 'W',
#        'formType': 'W'},
#       {'formLabel': 'Draw', 'formLabelAbbreviation': 'D', 'formType': 'D'},
#       {'formLabel': 'Lose', 'formLabelAbbreviation': 'L', 'formType': 'L'},
#       {'formLabel': 'Lose', 'formLabelAbbreviation': 'L', 'formType': 'L'},
#       {'formLabel': 'Draw', 'formLabelAbbreviation': 'D', 'formType': 'D'},
#       {'formLabel': 'Win', 'formLabelAbbreviation': 'W', 'formType': 'W'}],
#      'statsUnit': None,
#      'statsUnitAbbreviation': None}],
#    'qualification': None,
#    'teamId': 'nwsl::Football_Team::ac29701756da44a08457762380c10733',
#    'providerId': 'opta:Team:dtucewmt49th1p4selfutmnmc',
#    'shortName': 'Racing Lou',
#    'officialName': 'Racing Louisville FC',
#    'acronymName': 'LOU',
#    'mediaName': 'Racing Lou',
#    'mediaShortName': 'Racing Lou'},
#   {'stats': [{'statsId': 'rank',
#      'statsLabel': 'Rank',
#      'statsLabelAbbreviation': 'Rank',
#      'statsValue': 9,
#      'statsUnit': None,
#      'statsUnitAbbreviation': None},
#     {'statsId': 'team',
#      'statsLabel': 'Club',
#      'statsLabelAbbreviation': 'Club',
#      'statsValue': None,
#      'statsUnit': None,
#      'statsUnitAbbreviation': None},
#     {'statsId': 'points',
#      'statsLabel': 'Points',
#      'statsLabelAbbreviation': 'PTS',
#      'statsValue': 12,
#      'statsUnit': None,
#      'statsUnitAbbreviation': None},
#     {'statsId': 'matches-played',
#      'statsLabel': 'Matches played',
#      'statsLabelAbbreviation': 'P',
#      'statsValue': 10,
#      'statsUnit': None,
#      'statsUnitAbbreviation': None},
#     {'statsId': 'win',
#      'statsLabel': 'Win',
#      'statsLabelAbbreviation': 'W',
#      'statsValue': 3,
#      'statsUnit': None,
#      'statsUnitAbbreviation': None},
#     {'statsId': 'draw',
#      'statsLabel': 'Draw',
#      'statsLabelAbbreviation': 'D',
#      'statsValue': 3,
#      'statsUnit': None,
#      'statsUnitAbbreviation': None},
#     {'statsId': 'lose',
#      'statsLabel': 'Lose',
#      'statsLabelAbbreviation': 'L',
#      'statsValue': 4,
#      'statsUnit': None,
#      'statsUnitAbbreviation': None},
#     {'statsId': 'goals-for',
#      'statsLabel': 'Goals for',
#      'statsLabelAbbreviation': 'GF',
#      'statsValue': 9,
#      'statsUnit': None,
#      'statsUnitAbbreviation': None},
#     {'statsId': 'goals-against',
#      'statsLabel': 'Goals against',
#      'statsLabelAbbreviation': 'GA',
#      'statsValue': 9,
#      'statsUnit': None,
#      'statsUnitAbbreviation': None},
#     {'statsId': 'goal-difference',
#      'statsLabel': 'Goal difference',
#      'statsLabelAbbreviation': 'GD',
#      'statsValue': 0,
#      'statsUnit': None,
#      'statsUnitAbbreviation': None},
#     {'statsId': 'movement',
#      'statsLabel': 'Movement',
#      'statsLabelAbbreviation': 'Movement',
#      'statsValue': 'down',
#      'statsUnit': None,
#      'statsUnitAbbreviation': None},
#     {'statsId': 'form',
#      'statsLabel': 'Form',
#      'statsLabelAbbreviation': 'Form',
#      'statsValue': [{'formLabel': 'Draw',
#        'formLabelAbbreviation': 'D',
#        'formType': 'D'},
#       {'formLabel': 'Lose', 'formLabelAbbreviation': 'L', 'formType': 'L'},
#       {'formLabel': 'Draw', 'formLabelAbbreviation': 'D', 'formType': 'D'},
#       {'formLabel': 'Win', 'formLabelAbbreviation': 'W', 'formType': 'W'},
#       {'formLabel': 'Lose', 'formLabelAbbreviation': 'L', 'formType': 'L'},
#       {'formLabel': 'Win', 'formLabelAbbreviation': 'W', 'formType': 'W'}],
#      'statsUnit': None,
#      'statsUnitAbbreviation': None}],
#    'qualification': None,
#    'teamId': 'nwsl::Football_Team::ca719042b34443c4bcfe380ca4850eaf',
#    'providerId': 'opta:Team:esvbnzqbyvxp2k570ez7h1a1g',
#    'shortName': 'San Diego Wave',
#    'officialName': 'San Diego Wave FC',
#    'acronymName': 'SD',
#    'mediaName': 'San Diego Wave',
#    'mediaShortName': 'San Diego Wave'},
#   {'stats': [{'statsId': 'rank',
#      'statsLabel': 'Rank',
#      'statsLabelAbbreviation': 'Rank',
#      'statsValue': 10,
#      'statsUnit': None,
#      'statsUnitAbbreviation': None},
#     {'statsId': 'team',
#      'statsLabel': 'Club',
#      'statsLabelAbbreviation': 'Club',
#      'statsValue': None,
#      'statsUnit': None,
#      'statsUnitAbbreviation': None},
#     {'statsId': 'points',
#      'statsLabel': 'Points',
#      'statsLabelAbbreviation': 'PTS',
#      'statsValue': 12,
#      'statsUnit': None,
#      'statsUnitAbbreviation': None},
#     {'statsId': 'matches-played',
#      'statsLabel': 'Matches played',
#      'statsLabelAbbreviation': 'P',
#      'statsValue': 11,
#      'statsUnit': None,
#      'statsUnitAbbreviation': None},
#     {'statsId': 'win',
#      'statsLabel': 'Win',
#      'statsLabelAbbreviation': 'W',
#      'statsValue': 3,
#      'statsUnit': None,
#      'statsUnitAbbreviation': None},
#     {'statsId': 'draw',
#      'statsLabel': 'Draw',
#      'statsLabelAbbreviation': 'D',
#      'statsValue': 3,
#      'statsUnit': None,
#      'statsUnitAbbreviation': None},
#     {'statsId': 'lose',
#      'statsLabel': 'Lose',
#      'statsLabelAbbreviation': 'L',
#      'statsValue': 5,
#      'statsUnit': None,
#      'statsUnitAbbreviation': None},
#     {'statsId': 'goals-for',
#      'statsLabel': 'Goals for',
#      'statsLabelAbbreviation': 'GF',
#      'statsValue': 11,
#      'statsUnit': None,
#      'statsUnitAbbreviation': None},
#     {'statsId': 'goals-against',
#      'statsLabel': 'Goals against',
#      'statsLabelAbbreviation': 'GA',
#      'statsValue': 18,
#      'statsUnit': None,
#      'statsUnitAbbreviation': None},
#     {'statsId': 'goal-difference',
#      'statsLabel': 'Goal difference',
#      'statsLabelAbbreviation': 'GD',
#      'statsValue': -7,
#      'statsUnit': None,
#      'statsUnitAbbreviation': None},
#     {'statsId': 'movement',
#      'statsLabel': 'Movement',
#      'statsLabelAbbreviation': 'Movement',
#      'statsValue': 'up',
#      'statsUnit': None,
#      'statsUnitAbbreviation': None},
#     {'statsId': 'form',
#      'statsLabel': 'Form',
#      'statsLabelAbbreviation': 'Form',
#      'statsValue': [{'formLabel': 'Win',
#        'formLabelAbbreviation': 'W',
#        'formType': 'W'},
#       {'formLabel': 'Lose', 'formLabelAbbreviation': 'L', 'formType': 'L'},
#       {'formLabel': 'Win', 'formLabelAbbreviation': 'W', 'formType': 'W'},
#       {'formLabel': 'Lose', 'formLabelAbbreviation': 'L', 'formType': 'L'},
#       {'formLabel': 'Draw', 'formLabelAbbreviation': 'D', 'formType': 'D'},
#       {'formLabel': 'Draw', 'formLabelAbbreviation': 'D', 'formType': 'D'}],
#      'statsUnit': None,
#      'statsUnitAbbreviation': None}],
#    'qualification': None,
#    'teamId': 'nwsl::Football_Team::ca3f464d6b794a9087d441d75961403f',
#    'providerId': 'opta:Team:c3v2ohfuzoqmc8ljm65hi80sj',
#    'shortName': 'Dash',
#    'officialName': 'Houston Dash',
#    'acronymName': 'HOU',
#    'mediaName': 'Dash',
#    'mediaShortName': 'Dash'},
#   {'stats': [{'statsId': 'rank',
#      'statsLabel': 'Rank',
#      'statsLabelAbbreviation': 'Rank',
#      'statsValue': 11,
#      'statsUnit': None,
#      'statsUnitAbbreviation': None},
#     {'statsId': 'team',
#      'statsLabel': 'Club',
#      'statsLabelAbbreviation': 'Club',
#      'statsValue': None,
#      'statsUnit': None,
#      'statsUnitAbbreviation': None},
#     {'statsId': 'points',
#      'statsLabel': 'Points',
#      'statsLabelAbbreviation': 'PTS',
#      'statsValue': 11,
#      'statsUnit': None,
#      'statsUnitAbbreviation': None},
#     {'statsId': 'matches-played',
#      'statsLabel': 'Matches played',
#      'statsLabelAbbreviation': 'P',
#      'statsValue': 10,
#      'statsUnit': None,
#      'statsUnitAbbreviation': None},
#     {'statsId': 'win',
#      'statsLabel': 'Win',
#      'statsLabelAbbreviation': 'W',
#      'statsValue': 3,
#      'statsUnit': None,
#      'statsUnitAbbreviation': None},
#     {'statsId': 'draw',
#      'statsLabel': 'Draw',
#      'statsLabelAbbreviation': 'D',
#      'statsValue': 2,
#      'statsUnit': None,
#      'statsUnitAbbreviation': None},
#     {'statsId': 'lose',
#      'statsLabel': 'Lose',
#      'statsLabelAbbreviation': 'L',
#      'statsValue': 5,
#      'statsUnit': None,
#      'statsUnitAbbreviation': None},
#     {'statsId': 'goals-for',
#      'statsLabel': 'Goals for',
#      'statsLabelAbbreviation': 'GF',
#      'statsValue': 11,
#      'statsUnit': None,
#      'statsUnitAbbreviation': None},
#     {'statsId': 'goals-against',
#      'statsLabel': 'Goals against',
#      'statsLabelAbbreviation': 'GA',
#      'statsValue': 16,
#      'statsUnit': None,
#      'statsUnitAbbreviation': None},
#     {'statsId': 'goal-difference',
#      'statsLabel': 'Goal difference',
#      'statsLabelAbbreviation': 'GD',
#      'statsValue': -5,
#      'statsUnit': None,
#      'statsUnitAbbreviation': None},
#     {'statsId': 'movement',
#      'statsLabel': 'Movement',
#      'statsLabelAbbreviation': 'Movement',
#      'statsValue': 'down',
#      'statsUnit': None,
#      'statsUnitAbbreviation': None},
#     {'statsId': 'form',
#      'statsLabel': 'Form',
#      'statsLabelAbbreviation': 'Form',
#      'statsValue': [{'formLabel': 'Draw',
#        'formLabelAbbreviation': 'D',
#        'formType': 'D'},
#       {'formLabel': 'Lose', 'formLabelAbbreviation': 'L', 'formType': 'L'},
#       {'formLabel': 'Lose', 'formLabelAbbreviation': 'L', 'formType': 'L'},
#       {'formLabel': 'Win', 'formLabelAbbreviation': 'W', 'formType': 'W'},
#       {'formLabel': 'Lose', 'formLabelAbbreviation': 'L', 'formType': 'L'},
#       {'formLabel': 'Win', 'formLabelAbbreviation': 'W', 'formType': 'W'}],
#      'statsUnit': None,
#      'statsUnitAbbreviation': None}],
#    'qualification': None,
#    'teamId': 'nwsl::Football_Team::9587b8ce40624165903b6bc9fd252634',
#    'providerId': 'opta:Team:6hbfgdczbi3yg4sdpqgtu6s',
#    'shortName': 'Angel City',
#    'officialName': 'Angel City FC',
#    'acronymName': 'LA',
#    'mediaName': 'Angel City',
#    'mediaShortName': 'Angel City'},
#   {'stats': [{'statsId': 'rank',
#      'statsLabel': 'Rank',
#      'statsLabelAbbreviation': 'Rank',
#      'statsValue': 12,
#      'statsUnit': None,
#      'statsUnitAbbreviation': None},
#     {'statsId': 'team',
#      'statsLabel': 'Club',
#      'statsLabelAbbreviation': 'Club',
#      'statsValue': None,
#      'statsUnit': None,
#      'statsUnitAbbreviation': None},
#     {'statsId': 'points',
#      'statsLabel': 'Points',
#      'statsLabelAbbreviation': 'PTS',
#      'statsValue': 9,
#      'statsUnit': None,
#      'statsUnitAbbreviation': None},
#     {'statsId': 'matches-played',
#      'statsLabel': 'Matches played',
#      'statsLabelAbbreviation': 'P',
#      'statsValue': 11,
#      'statsUnit': None,
#      'statsUnitAbbreviation': None},
#     {'statsId': 'win',
#      'statsLabel': 'Win',
#      'statsLabelAbbreviation': 'W',
#      'statsValue': 3,
#      'statsUnit': None,
#      'statsUnitAbbreviation': None},
#     {'statsId': 'draw',
#      'statsLabel': 'Draw',
#      'statsLabelAbbreviation': 'D',
#      'statsValue': 0,
#      'statsUnit': None,
#      'statsUnitAbbreviation': None},
#     {'statsId': 'lose',
#      'statsLabel': 'Lose',
#      'statsLabelAbbreviation': 'L',
#      'statsValue': 8,
#      'statsUnit': None,
#      'statsUnitAbbreviation': None},
#     {'statsId': 'goals-for',
#      'statsLabel': 'Goals for',
#      'statsLabelAbbreviation': 'GF',
#      'statsValue': 15,
#      'statsUnit': None,
#      'statsUnitAbbreviation': None},
#     {'statsId': 'goals-against',
#      'statsLabel': 'Goals against',
#      'statsLabelAbbreviation': 'GA',
#      'statsValue': 23,
#      'statsUnit': None,
#      'statsUnitAbbreviation': None},
#     {'statsId': 'goal-difference',
#      'statsLabel': 'Goal difference',
#      'statsLabelAbbreviation': 'GD',
#      'statsValue': -8,
#      'statsUnit': None,
#      'statsUnitAbbreviation': None},
#     {'statsId': 'movement',
#      'statsLabel': 'Movement',
#      'statsLabelAbbreviation': 'Movement',
#      'statsValue': 'down',
#      'statsUnit': None,
#      'statsUnitAbbreviation': None},
#     {'statsId': 'form',
#      'statsLabel': 'Form',
#      'statsLabelAbbreviation': 'Form',
#      'statsValue': [{'formLabel': 'Lose',
#        'formLabelAbbreviation': 'L',
#        'formType': 'L'},
#       {'formLabel': 'Win', 'formLabelAbbreviation': 'W', 'formType': 'W'},
#       {'formLabel': 'Lose', 'formLabelAbbreviation': 'L', 'formType': 'L'},
#       {'formLabel': 'Lose', 'formLabelAbbreviation': 'L', 'formType': 'L'},
#       {'formLabel': 'Lose', 'formLabelAbbreviation': 'L', 'formType': 'L'},
#       {'formLabel': 'Lose', 'formLabelAbbreviation': 'L', 'formType': 'L'}],
#      'statsUnit': None,
#      'statsUnitAbbreviation': None}],
#    'qualification': None,
#    'teamId': 'nwsl::Football_Team::19674698cec24f53af8866cd21abaf8f',
#    'providerId': 'opta:Team:eka22bj7co8bw5qxa6qlbinf8',
#    'shortName': 'Bay',
#    'officialName': 'Bay FC',
#    'acronymName': 'BAY',
#    'mediaName': 'Bay',
#    'mediaShortName': 'Bay'},
#   {'stats': [{'statsId': 'rank',
#      'statsLabel': 'Rank',
#      'statsLabelAbbreviation': 'Rank',
#      'statsValue': 13,
#      'statsUnit': None,
#      'statsUnitAbbreviation': None},
#     {'statsId': 'team',
#      'statsLabel': 'Club',
#      'statsLabelAbbreviation': 'Club',
#      'statsValue': None,
#      'statsUnit': None,
#      'statsUnitAbbreviation': None},
#     {'statsId': 'points',
#      'statsLabel': 'Points',
#      'statsLabelAbbreviation': 'PTS',
#      'statsValue': 7,
#      'statsUnit': None,
#      'statsUnitAbbreviation': None},
#     {'statsId': 'matches-played',
#      'statsLabel': 'Matches played',
#      'statsLabelAbbreviation': 'P',
#      'statsValue': 11,
#      'statsUnit': None,
#      'statsUnitAbbreviation': None},
#     {'statsId': 'win',
#      'statsLabel': 'Win',
#      'statsLabelAbbreviation': 'W',
#      'statsValue': 2,
#      'statsUnit': None,
#      'statsUnitAbbreviation': None},
#     {'statsId': 'draw',
#      'statsLabel': 'Draw',
#      'statsLabelAbbreviation': 'D',
#      'statsValue': 1,
#      'statsUnit': None,
#      'statsUnitAbbreviation': None},
#     {'statsId': 'lose',
#      'statsLabel': 'Lose',
#      'statsLabelAbbreviation': 'L',
#      'statsValue': 8,
#      'statsUnit': None,
#      'statsUnitAbbreviation': None},
#     {'statsId': 'goals-for',
#      'statsLabel': 'Goals for',
#      'statsLabelAbbreviation': 'GF',
#      'statsValue': 11,
#      'statsUnit': None,
#      'statsUnitAbbreviation': None},
#     {'statsId': 'goals-against',
#      'statsLabel': 'Goals against',
#      'statsLabelAbbreviation': 'GA',
#      'statsValue': 20,
#      'statsUnit': None,
#      'statsUnitAbbreviation': None},
#     {'statsId': 'goal-difference',
#      'statsLabel': 'Goal difference',
#      'statsLabelAbbreviation': 'GD',
#      'statsValue': -9,
#      'statsUnit': None,
#      'statsUnitAbbreviation': None},
#     {'statsId': 'movement',
#      'statsLabel': 'Movement',
#      'statsLabelAbbreviation': 'Movement',
#      'statsValue': 'stable',
#      'statsUnit': None,
#      'statsUnitAbbreviation': None},
#     {'statsId': 'form',
#      'statsLabel': 'Form',
#      'statsLabelAbbreviation': 'Form',
#      'statsValue': [{'formLabel': 'Lose',
#        'formLabelAbbreviation': 'L',
#        'formType': 'L'},
#       {'formLabel': 'Lose', 'formLabelAbbreviation': 'L', 'formType': 'L'},
#       {'formLabel': 'Lose', 'formLabelAbbreviation': 'L', 'formType': 'L'},
#       {'formLabel': 'Draw', 'formLabelAbbreviation': 'D', 'formType': 'D'},
#       {'formLabel': 'Win', 'formLabelAbbreviation': 'W', 'formType': 'W'},
#       {'formLabel': 'Lose', 'formLabelAbbreviation': 'L', 'formType': 'L'}],
#      'statsUnit': None,
#      'statsUnitAbbreviation': None}],
#    'qualification': None,
#    'teamId': 'nwsl::Football_Team::1151140adfc24339ba1c93cb0b6b0238',
#    'providerId': 'opta:Team:bl53jk6zlfe5f583pil7xzwi5',
#    'shortName': 'Reign',
#    'officialName': 'Seattle Reign',
#    'acronymName': 'SEA',
#    'mediaName': 'Reign',
#    'mediaShortName': 'Reign'},
#   {'stats': [{'statsId': 'rank',
#      'statsLabel': 'Rank',
#      'statsLabelAbbreviation': 'Rank',
#      'statsValue': 14,
#      'statsUnit': None,
#      'statsUnitAbbreviation': None},
#     {'statsId': 'team',
#      'statsLabel': 'Club',
#      'statsLabelAbbreviation': 'Club',
#      'statsValue': None,
#      'statsUnit': None,
#      'statsUnitAbbreviation': None},
#     {'statsId': 'points',
#      'statsLabel': 'Points',
#      'statsLabelAbbreviation': 'PTS',
#      'statsValue': 4,
#      'statsUnit': None,
#      'statsUnitAbbreviation': None},
#     {'statsId': 'matches-played',
#      'statsLabel': 'Matches played',
#      'statsLabelAbbreviation': 'P',
#      'statsValue': 11,
#      'statsUnit': None,
#      'statsUnitAbbreviation': None},
#     {'statsId': 'win',
#      'statsLabel': 'Win',
#      'statsLabelAbbreviation': 'W',
#      'statsValue': 1,
#      'statsUnit': None,
#      'statsUnitAbbreviation': None},
#     {'statsId': 'draw',
#      'statsLabel': 'Draw',
#      'statsLabelAbbreviation': 'D',
#      'statsValue': 1,
#      'statsUnit': None,
#      'statsUnitAbbreviation': None},
#     {'statsId': 'lose',
#      'statsLabel': 'Lose',
#      'statsLabelAbbreviation': 'L',
#      'statsValue': 9,
#      'statsUnit': None,
#      'statsUnitAbbreviation': None},
#     {'statsId': 'goals-for',
#      'statsLabel': 'Goals for',
#      'statsLabelAbbreviation': 'GF',
#      'statsValue': 6,
#      'statsUnit': None,
#      'statsUnitAbbreviation': None},
#     {'statsId': 'goals-against',
#      'statsLabel': 'Goals against',
#      'statsLabelAbbreviation': 'GA',
#      'statsValue': 20,
#      'statsUnit': None,
#      'statsUnitAbbreviation': None},
#     {'statsId': 'goal-difference',
#      'statsLabel': 'Goal difference',
#      'statsLabelAbbreviation': 'GD',
#      'statsValue': -14,
#      'statsUnit': None,
#      'statsUnitAbbreviation': None},
#     {'statsId': 'movement',
#      'statsLabel': 'Movement',
#      'statsLabelAbbreviation': 'Movement',
#      'statsValue': 'stable',
#      'statsUnit': None,
#      'statsUnitAbbreviation': None},
#     {'statsId': 'form',
#      'statsLabel': 'Form',
#      'statsLabelAbbreviation': 'Form',
#      'statsValue': [{'formLabel': 'Lose',
#        'formLabelAbbreviation': 'L',
#        'formType': 'L'},
#       {'formLabel': 'Lose', 'formLabelAbbreviation': 'L', 'formType': 'L'},
#       {'formLabel': 'Lose', 'formLabelAbbreviation': 'L', 'formType': 'L'},
#       {'formLabel': 'Lose', 'formLabelAbbreviation': 'L', 'formType': 'L'},
#       {'formLabel': 'Lose', 'formLabelAbbreviation': 'L', 'formType': 'L'},
#       {'formLabel': 'Draw', 'formLabelAbbreviation': 'D', 'formType': 'D'}],
#      'statsUnit': None,
#      'statsUnitAbbreviation': None}],
#    'qualification': None,
#    'teamId': 'nwsl::Football_Team::acffc559cf7d485a9c05fa23ab57054b',
#    'providerId': 'opta:Team:bn7w86uw8j61dga3xr5s0yiju',
#    'shortName': 'Royals',
#    'officialName': 'Utah Royals FC',
#    'acronymName': 'UTA',
#    'mediaName': 'Royals',
#    'mediaShortName': 'Royals'}],
#  'legenda': [],
#  'apiCallRequestTime': '2024-05-27T22:46:27.7336598+00:00'}

# %%
def convert_team(t):
    stats = {}
    for stat in t["stats"]:
        stats[stat["statsId"]] = stat["statsValue"]
    return [
        t["acronymName"],
        stats["rank"],
        stats["points"],
        stats["matches-played"],
        stats["win"],
        stats["lose"],
        stats["draw"],
        stats["goals-for"],
        stats["goals-against"],
        stats["goal-difference"],
    ]


df = pd.DataFrame(
    map(convert_team, data["teams"]),
    columns=[
        "team",
        "rank",
        "PTS",
        "MP",
        "W",
        "L",
        "D",
        "GF",
        "GA",
        "GD"
    ],
)
df = df.replace("KC", "KCC")
df = df.replace("NJY", "NJNY")
df = df.replace("SEA", "RGN")
df
# Out:
#     team  rank  PTS  MP  W  L  D  GF  GA  GD
# 0    ORL     1   27  11  8  0  3  20  10  10
# 1    KCC     2   25  11  7  0  4  26  15  11
# 2    WAS     3   24  11  8  3  0  25  16   9
# 3    POR     4   19  11  6  4  1  24  16   8
# 4   NJNY     5   18  10  5  2  3  10   7   3
# 5    CHI     6   16  11  5  5  1  15  15   0
# 6     NC     7   15  11  5  6  0  13  14  -1
# 7    LOU     8   12  10  2  2  6  15  12   3
# 8     SD     9   12  10  3  4  3   9   9   0
# 9    HOU    10   12  11  3  5  3  11  18  -7
# 10    LA    11   11  10  3  5  2  11  16  -5
# 11   BAY    12    9  11  3  8  0  15  23  -8
# 12   RGN    13    7  11  2  8  1  11  20  -9
# 13   UTA    14    4  11  1  9  1   6  20 -14

# %%
df.to_csv("data/" + str(year) + "/" + str(week) + ".csv", index=False)
