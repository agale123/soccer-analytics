# %%
import pandas as pd

# %%
results = pd.read_csv("results.csv")
results
# Out:
#      year           team result
# 0    1991          China      Q
# 1    1991         Norway      2
# 2    1991        Denmark      Q
# 3    1991    New Zealand      G
# 4    1991  United States      1
# ..    ...            ...    ...
# 163  2023      Argentina      ?
# 164  2023        Germany      ?
# 165  2023        Morocco      ?
# 166  2023       Colombia      ?
# 167  2023    South Korea      ?
#
# [168 rows x 3 columns]

# %%
feds = pd.read_csv("federations.csv")
feds
# Out:
#                  team federation
# 0               China        AFC
# 1              Norway       UEFA
# 2             Denmark       UEFA
# 3         New Zealand        OFC
# 4       United States   CONCACAF
# 5              Sweden       UEFA
# 6              Brazil   CONMEBOL
# 7               Japan        AFC
# 8             Germany       UEFA
# 9               Italy       UEFA
# 10     Chinese Taipei        AFC
# 11            Nigeria        CAF
# 12            England       UEFA
# 13             Canada   CONCACAF
# 14          Australia        AFC
# 15        North Korea        AFC
# 16             Mexico   CONCACAF
# 17             Russia       UEFA
# 18              Ghana        CAF
# 19             France       UEFA
# 20        South Korea        AFC
# 21          Argentina   CONMEBOL
# 22           Colombia   CONMEBOL
# 23  Equatorial Guinea        CAF
# 24        Netherlands       UEFA
# 25           Thailand        AFC
# 26        Ivory Coast        CAF
# ...

# %%
hosts = pd.read_csv("host.csv")
hosts
# Out:
#    year           host
# 0  1991          China
# 1  1995         Sweden
# 2  1999  United States
# 3  2003  United States
# 4  2007          China
# 5  2011        Germany
# 6  2015         Canada
# 7  2019         France
# 8  2023      Australia
# 9  2023    New Zealand

# %%
df = (
    results.pivot(index="team", columns="year", values="result")
    .rename_axis(None, axis=1)
)
df
# Out:
#                   1991 1995 1999 2003 2007 2011 2015 2019 2023
# team
# Argentina          NaN  NaN  NaN    G    G  NaN  NaN    G    ?
# Australia          NaN    G    G    G    Q    Q    Q   16    ?
# Brazil               G    G    3    Q    2    Q   16   16    ?
# Cameroon           NaN  NaN  NaN  NaN  NaN  NaN   16   16  NaN
# Canada             NaN    G    G    4    G    G    Q   16    ?
# Chile              NaN  NaN  NaN  NaN  NaN  NaN  NaN    G  NaN
# China                Q    4    2    Q    Q  NaN    Q   16    ?
# Chinese Taipei       Q  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Colombia           NaN  NaN  NaN  NaN  NaN    G   16  NaN    ?
# Costa Rica         NaN  NaN  NaN  NaN  NaN  NaN    G  NaN    ?
# Denmark              Q    Q    G  NaN    G  NaN  NaN  NaN    ?
# Ecuador            NaN  NaN  NaN  NaN  NaN  NaN    G  NaN  NaN
# England            NaN    Q  NaN  NaN    Q    Q    3    4    ?
# Equatorial Guinea  NaN  NaN  NaN  NaN  NaN    G  NaN  NaN  NaN
# ...

# %%
df = (
    df.join(feds.set_index("team"))
    .sort_index(axis=0)
    .sort_values(["federation"], kind="stable")
)
df
# Out:
#                   1991 1995 1999 2003 2007 2011 2015 2019 2023 federation
# team
# Australia          NaN    G    G    G    Q    Q    Q   16    ?        AFC
# China                Q    4    2    Q    Q  NaN    Q   16    ?        AFC
# Chinese Taipei       Q  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN        AFC
# Japan                G    Q    G    G    G    1    2   16    ?        AFC
# North Korea        NaN  NaN    G    G    Q    G  NaN  NaN  NaN        AFC
# Philippines        NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN    ?        AFC
# South Korea        NaN  NaN  NaN    G  NaN  NaN   16    G    ?        AFC
# Thailand           NaN  NaN  NaN  NaN  NaN  NaN    G    G  NaN        AFC
# Vietnam            NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN    ?        AFC
# Cameroon           NaN  NaN  NaN  NaN  NaN  NaN   16   16  NaN        CAF
# Equatorial Guinea  NaN  NaN  NaN  NaN  NaN    G  NaN  NaN  NaN        CAF
# Ghana              NaN  NaN    G    G    G  NaN  NaN  NaN  NaN        CAF
# ...

# %%
df.to_csv("merged.csv")
